# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
from sklearn import preprocessing
import seaborn as sns
import pickle
from sklearn.decomposition import PCA, SparsePCA
from sklearn.preprocessing import LabelEncoder, StandardScaler, minmax_scale

# %%
df_identity_train = pd.read_csv("../Data/train_identity.csv")
df_transaction_train = pd.read_csv("../Data/train_transaction.csv")
df_identity_test = pd.read_csv("../Data/test_identity.csv")
df_transaction_test = pd.read_csv("../Data/test_transaction.csv")

# %%
# Seen from https://www.kaggle.com/kabure/almost-complete-feature-engineering-ieee-data#V-Features
def PCA_change(df, cols, n_components, prefix='PCA_', rand_seed=4):
    pca = PCA(n_components=n_components, random_state=rand_seed)

    principalComponents = pca.fit_transform(df[cols])

    principalDf = pd.DataFrame(principalComponents)

    df.drop(cols, axis=1, inplace=True)

    principalDf.rename(columns=lambda x: str(prefix)+str(x), inplace=True)

    df = pd.concat([df, principalDf], axis=1)
    
    return df

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        # print(name)
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
pd.set_option("display.max_rows", 500)

# %%
df_train = pd.merge(df_transaction_train, df_identity_train, how = "left", on = "TransactionID")
df_test = pd.merge(df_transaction_test, df_identity_test, how = "left", on = "TransactionID")

# %%
print("shape of df_identity_train: ", df_identity_train.shape)
print("shape of df_transaction_train: ", df_transaction_train.shape)
print("shape of df_train: ", df_train.shape)
# Out:
# shape of df_identity_train:  (144233, 41)
# shape of df_transaction_train:  (590540, 394)
# shape of df_train:  (590540, 434)

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: 
        print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
one_val_cols =      [col for col in df_train.columns if df_train[col].nunique()<=1] +\
                        [col for col in df_test.columns if df_test[col].nunique()<=1]
missing_val_cols =  [col for col in df_train.columns if df_train[col].isnull().sum()/df_train.shape[0]>0.9] +\
                        [col for col in df_test.columns if df_test[col].isnull().sum()/df_test.shape[0]>0.9]
same_val_cols =     [col for col in df_train.columns if df_train[col].value_counts(dropna=False, normalize=True).values[0] > 0.9] +\
                        [col for col in df_test.columns if df_test[col].value_counts(dropna=False, normalize=True).values[0] > 0.9]
cols_to_drop = list(set(one_val_cols + missing_val_cols + same_val_cols))
print(cols_to_drop)
# Out:
# ['V108', 'V136', 'V65', 'V301', 'V309', 'V114', 'V67', 'V115', 'V320', 'V113', 'V104', 'V125', 'V298', 'D7', 'V286', 'V27', 'V319', 'V133', 'V28', 'id_21', 'V25', 'V86', 'V132', 'V14', 'dist2', 'V281', 'V88', 'V305', 'V55', 'V134', 'V26', 'V297', 'V101', 'V107', 'V119', 'V106', 'V105', 'V135', 'id_25', 'id_08', 'V118', 'id_07', 'V98', 'V311', 'V102', 'V121', 'V316', 'V112', 'C3', 'id_27', 'V295', 'id_23', 'id_18', 'V110', 'V23', 'V89', 'V117', 'V137', 'V68', 'V318', 'id_24', 'V109', 'V284', 'V123', 'id_22', 'id_26', 'V24', 'V116', 'V124', 'V299', 'V321', 'V66', 'V111', 'V293', 'V296', 'V77', 'V120', 'V122', 'V300', 'V129', 'V103', 'V290', 'isFraud']

# %%
cols_to_drop.remove('isFraud')

# %%
df_train.drop(cols_to_drop, axis = 1, inplace = True)
df_test.drop(cols_to_drop, axis = 1, inplace = True)

# df_train.fillna(-999, inplace = True)
# df_test.fillna(-999, inplace = True)

# %%
def make_day_feature(df, offset=0.58, tname='TransactionDT'):
    """
    Creates a day of the week feature, encoded as 0-6.
    """
    days = df[tname] / (3600 * 24)
    encoded_days = np.floor(days - 1 + offset) % 7
    return encoded_days

def make_hour_feature(df, tname='TransactionDT'):
    """
    Creates an hour of the day feature, encoded as 0-23.
    """
    hours = df[tname] / (3600)
    encoded_hours = np.floor(hours) % 24
    return encoded_hours

# %%
df_train["Weekday"] = make_day_feature(df_train)
df_train["Hour"]= make_hour_feature(df_train)
df_test["Weekday"] = make_day_feature(df_test)
df_test["Hour"] = make_hour_feature(df_test)

# %%
emails = {'gmail': 'google', 'att.net': 'att', 'twc.com': 'spectrum', 'scranton.edu': 'other', 
          'optonline.net': 'other', 'hotmail.co.uk': 'microsoft', 'comcast.net': 'other', 'yahoo.com.mx': 'yahoo', 
          'yahoo.fr': 'yahoo', 'yahoo.es': 'yahoo', 'charter.net': 'spectrum', 'live.com': 'microsoft', 
          'aim.com': 'aol', 'hotmail.de': 'microsoft', 'centurylink.net': 'centurylink', 'gmail.com': 'google', 
          'me.com': 'apple', 'earthlink.net': 'other', 'gmx.de': 'other', 'web.de': 'other', 'cfl.rr.com': 'other', 
          'hotmail.com': 'microsoft', 'protonmail.com': 'other', 'hotmail.fr': 'microsoft', 'windstream.net': 'other',
          'outlook.es': 'microsoft', 'yahoo.co.jp': 'yahoo', 'yahoo.de': 'yahoo', 'servicios-ta.com': 'other', 
          'netzero.net': 'other', 'suddenlink.net': 'other', 'roadrunner.com': 'other', 'sc.rr.com': 'other', 
          'live.fr': 'microsoft', 'verizon.net': 'yahoo', 'msn.com': 'microsoft', 'q.com': 'centurylink', 
          'prodigy.net.mx': 'att', 'frontier.com': 'yahoo', 'anonymous.com': 'other', 
          'rocketmail.com': 'yahoo', 'sbcglobal.net': 'att', 'frontiernet.net': 'yahoo', 'ymail.com': 'yahoo', 
          'outlook.com': 'microsoft', 'mail.com': 'other', 'bellsouth.net': 'other', 
          'embarqmail.com': 'centurylink', 'cableone.net': 'other', 'hotmail.es': 'microsoft', 'mac.com': 'apple', 
          'yahoo.co.uk': 'yahoo', 'netzero.com': 'other', 'yahoo.com': 'yahoo', 'live.com.mx': 'microsoft', 
          'ptd.net': 'other', 'cox.net': 'other', 'aol.com': 'aol', 'juno.com': 'other', 'icloud.com': 'apple',
          -999:"undefined"}
us_emails = ['gmail', 'net', 'edu']
# https://www.kaggle.com/c/ieee-fraud-detection/discussion/100499#latest_df-579654
for col in ['P_emaildomain', 'R_emaildomain']:
    df_train[col + '_pre'] = df_train[col].map(emails)
    df_test[col + '_pre'] = df_test[col].map(emails)
    
    df_train[col + '_suffix'] = df_train[col].map(lambda x: str(x).split('.')[-1])
    df_test[col + '_suffix'] = df_test[col].map(lambda x: str(x).split('.')[-1])
    
    df_train[col + '_suffix'] = df_train[col + '_suffix'].map(lambda x: x if str(x) not in us_emails else 'us')
    df_test[col + '_suffix'] = df_test[col + '_suffix'].map(lambda x: x if str(x) not in us_emails else 'us')

# %%
categorical = ["ProductCD", "card1", "card2", "card3", "card4", "card5", "card6", "addr1", "addr2",
               "P_emaildomain", "R_emaildomain"] +  ["M" + str(i) for i in range(1, 10)] +\
                    ['DeviceType', 'DeviceInfo', 'Weekday', 'Hour',
                     'P_emaildomain_pre', 'P_emaildomain_suffix', 'R_emaildomain_pre',
                     'R_emaildomain_suffix', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16', 'id_17', 'id_19', 'id_20', 
                     'id_28', 'id_29', 'id_30', 'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38']

# %%
# Label encoding
category_counts = {}
for col in categorical:
    df_train[col] = df_train[col].replace("nan", "other")
    df_train[col] = df_train[col].replace(np.nan, "other")
    df_test[col] = df_test[col].replace("nan", "other")
    df_test[col] = df_test[col].replace(np.nan, "other")
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(df_train[col].values) + list(df_test[col].values))
    df_train[col] = lbl.transform(list(df_train[col].values))
    df_test[col] = lbl.transform(list(df_test[col].values))
    category_counts[col] = len(list(lbl.classes_)) + 1

# %%
category_counts
# Out:
# {'ProductCD': 6,
#  'card1': 17092,
#  'card2': 503,
#  'card3': 135,
#  'card4': 6,
#  'card5': 140,
#  'card6': 6,
#  'addr1': 443,
#  'addr2': 95,
#  'P_emaildomain': 62,
#  'R_emaildomain': 62,
#  'M1': 4,
#  'M2': 4,
#  'M3': 4,
#  'M4': 5,
#  'M5': 4,
#  'M6': 4,
#  'M7': 4,
#  'M8': 4,
#  'M9': 4,
#  'DeviceType': 4,
#  'DeviceInfo': 2801,
#  'Weekday': 8,
#  'Hour': 25,
#  'P_emaildomain_pre': 10,
#  'P_emaildomain_suffix': 10,
#  'R_emaildomain_pre': 10,
#  'R_emaildomain_suffix': 10,
#  'id_12': 4,
#  'id_13': 57,
#  'id_14': 30,
#  'id_15': 5,
#  'id_16': 4,
#  'id_17': 129,
#  'id_19': 570,
#  'id_20': 549,
#  'id_28': 4,
#  'id_29': 4,
#  'id_30': 88,
#  'id_31': 173,
#  'id_32': 8,
#  'id_33': 463,
#  'id_34': 6,
#  'id_35': 4,
#  'id_36': 4,
#  'id_37': 4,
#  'id_38': 4}

# %%
del df_train["TransactionID"]
del df_train["TransactionDT"]
del df_test["TransactionID"]
del df_test["TransactionDT"]

# %%
resumetable(df_train)
# Out:
# Dataset Shape: (590540, 358)
#                      Name   dtypes  Missing  Uniques  First Value  \
# 0           TransactionID    int64        0   590540    2987000.0
# 1                 isFraud    int64        0        2          0.0
# 2           TransactionDT    int64        0   573349      86400.0
# 3          TransactionAmt  float64        0    20902         68.5
# 4               ProductCD    int64        0        5          4.0
# 5                   card1    int64        0    13553      12696.0
# 6                   card2    int64        0      501        501.0
# 7                   card3    int64        0      115         50.0
# 8                   card4    int64        0        5          1.0
# 9                   card5    int64        0      120         42.0
# 10                  card6    int64        0        5          1.0
# 11                  addr1    int64        0      333        215.0
# 12                  addr2    int64        0       75         80.0
# 13                  dist1  float64   352271     2651         19.0
# 14          P_emaildomain    int64        0       60         35.0
# 15          R_emaildomain    int64        0       61         35.0
# 16                     C1  float64        0     1657          1.0
# 17                     C2  float64        0     1216          1.0
# 18                     C4  float64        0     1260          0.0
# 19                     C5  float64        0      319          0.0
# 20                     C6  float64        0     1328          1.0
# 21                     C7  float64        0     1103          0.0
# 22                     C8  float64        0     1253          0.0
# 23                     C9  float64        0      205          1.0
# 24                    C10  float64        0     1231          0.0
# 25                    C11  float64        0     1476          2.0
# 26                    C12  float64        0     1199          0.0
# 27                    C13  float64        0     1597          1.0
# 28                    C14  float64        0     1108          1.0
# 29                     D1  float64     1269      641         14.0
# 30                     D2  float64   280797      641          NaN
# 31                     D3  float64   262878      649         13.0
# 32                     D4  float64   168922      808          NaN
# 33                     D5  float64   309841      688          NaN
# 34                     D6  float64   517353      829          NaN
# 35                     D8  float64   515614    12353          NaN
# 36                     D9  float64   515614       24          NaN
# 37                    D10  float64    76022      818         13.0
# 38                    D11  float64   279287      676         13.0
# 39                    D12  float64   525823      635          NaN
# 40                    D13  float64   528588      577          NaN
# 41                    D14  float64   528353      802          NaN
# 42                    D15  float64    89113      859          0.0
# 43                     M1    int64        0        3          1.0
# 44                     M2    int64        0        3          1.0
# 45                     M3    int64        0        3          1.0
# 46                     M4    int64        0        4          2.0
# 47                     M5    int64        0        3          0.0
# 48                     M6    int64        0        3          1.0
# 49                     M7    int64        0        3          2.0
# 50                     M8    int64        0        3          2.0
# 51                     M9    int64        0        3          2.0
# 52                     V1  float64   279287        2          1.0
# 53                     V2  float64   279287        9          1.0
# 54                     V3  float64   279287       10          1.0
# 55                     V4  float64   279287        7          1.0
# 56                     V5  float64   279287        7          1.0
# 57                     V6  float64   279287       10          1.0
# 58                     V7  float64   279287       10          1.0
# 59                     V8  float64   279287        9          1.0
# 60                     V9  float64   279287        9          1.0
# 61                    V10  float64   279287        5          0.0
# 62                    V11  float64   279287        6          0.0
# 63                    V12  float64    76073        4          1.0
# 64                    V13  float64    76073        7          1.0
# 65                    V15  float64    76073        8          0.0
# 66                    V16  float64    76073       15          0.0
# 67                    V17  float64    76073       16          0.0
# 68                    V18  float64    76073       16          0.0
# 69                    V19  float64    76073        8          1.0
# 70                    V20  float64    76073       15          1.0
# 71                    V21  float64    76073        6          0.0
# 72                    V22  float64    76073        9          0.0
# 73                    V29  float64    76073        6          0.0
# 74                    V30  float64    76073        8          0.0
# 75                    V31  float64    76073        8          0.0
# 76                    V32  float64    76073       15          0.0
# 77                    V33  float64    76073        7          0.0
# 78                    V34  float64    76073       13          0.0
# 79                    V35  float64   168969        4          NaN
# 80                    V36  float64   168969        6          NaN
# 81                    V37  float64   168969       55          NaN
# 82                    V38  float64   168969       55          NaN
# 83                    V39  float64   168969       16          NaN
# 84                    V40  float64   168969       18          NaN
# 85                    V41  float64   168969        2          NaN
# 86                    V42  float64   168969        9          NaN
# 87                    V43  float64   168969        9          NaN
# 88                    V44  float64   168969       49          NaN
# 89                    V45  float64   168969       49          NaN
# 90                    V46  float64   168969        7          NaN
# 91                    V47  float64   168969        9          NaN
# 92                    V48  float64   168969        6          NaN
# 93                    V49  float64   168969        6          NaN
# 94                    V50  float64   168969        6          NaN
# 95                    V51  float64   168969        7          NaN
# 96                    V52  float64   168969        9          NaN
# 97                    V53  float64    77096        6          1.0
# 98                    V54  float64    77096        7          1.0
# 99                    V56  float64    77096       52          1.0
# 100                   V57  float64    77096        7          0.0
# 101                   V58  float64    77096       11          0.0
# 102                   V59  float64    77096       17          0.0
# 103                   V60  float64    77096       17          0.0
# 104                   V61  float64    77096        7          1.0
# 105                   V62  float64    77096       11          1.0
# 106                   V63  float64    77096        8          0.0
# 107                   V64  float64    77096        8          0.0
# 108                   V69  float64    77096        6          0.0
# 109                   V70  float64    77096        7          0.0
# 110                   V71  float64    77096        7          0.0
# 111                   V72  float64    77096       11          0.0
# 112                   V73  float64    77096        8          0.0
# 113                   V74  float64    77096        9          0.0
# 114                   V75  float64    89164        5          1.0
# 115                   V76  float64    89164        7          1.0
# 116                   V78  float64    89164       32          1.0
# 117                   V79  float64    89164        8          0.0
# 118                   V80  float64    89164       20          0.0
# 119                   V81  float64    89164       20          0.0
# 120                   V82  float64    89164        8          0.0
# 121                   V83  float64    89164        8          0.0
# 122                   V84  float64    89164        8          0.0
# 123                   V85  float64    89164        8          0.0
# 124                   V87  float64    89164       31          1.0
# 125                   V90  float64    89164        6          0.0
# 126                   V91  float64    89164        7          0.0
# 127                   V92  float64    89164        8          0.0
# 128                   V93  float64    89164        8          0.0
# 129                   V94  float64    89164        3          0.0
# 130                   V95  float64      314      881          0.0
# 131                   V96  float64      314     1410          1.0
# 132                   V97  float64      314      976          0.0
# 133                   V99  float64      314       89          0.0
# 134                  V100  float64      314       29          0.0
# 135                  V126  float64      314    10299          0.0
# 136                  V127  float64      314    24414        117.0
# 137                  V128  float64      314    14507          0.0
# 138                  V130  float64      314    12332          0.0
# 139                  V131  float64      314     4444          0.0
# 140                  V138  float64   508595       23          NaN
# 141                  V139  float64   508595       34          NaN
# 142                  V140  float64   508595       34          NaN
# 143                  V141  float64   508595        6          NaN
# 144                  V142  float64   508595       10          NaN
# 145                  V143  float64   508589      870          NaN
# 146                  V144  float64   508589       63          NaN
# 147                  V145  float64   508589      260          NaN
# 148                  V146  float64   508595       25          NaN
# 149                  V147  float64   508595       27          NaN
# 150                  V148  float64   508595       21          NaN
# 151                  V149  float64   508595       21          NaN
# 152                  V150  float64   508589     1996          NaN
# 153                  V151  float64   508589       56          NaN
# 154                  V152  float64   508589       39          NaN
# 155                  V153  float64   508595       19          NaN
# 156                  V154  float64   508595       19          NaN
# 157                  V155  float64   508595       25          NaN
# 158                  V156  float64   508595       25          NaN
# 159                  V157  float64   508595       25          NaN
# 160                  V158  float64   508595       25          NaN
# 161                  V159  float64   508589     6663          NaN
# 162                  V160  float64   508589     9621          NaN
# 163                  V161  float64   508595       79          NaN
# 164                  V162  float64   508595      185          NaN
# 165                  V163  float64   508595      106          NaN
# 166                  V164  float64   508589     1978          NaN
# 167                  V165  float64   508589     2547          NaN
# 168                  V166  float64   508589      987          NaN
# 169                  V167  float64   450909      873          NaN
# 170                  V168  float64   450909      965          NaN
# 171                  V169  float64   450721       20          NaN
# 172                  V170  float64   450721       49          NaN
# 173                  V171  float64   450721       62          NaN
# 174                  V172  float64   450909       32          NaN
# 175                  V173  float64   450909        8          NaN
# 176                  V174  float64   450721        9          NaN
# 177                  V175  float64   450721       15          NaN
# 178                  V176  float64   450909       49          NaN
# 179                  V177  float64   450909      862          NaN
# 180                  V178  float64   450909     1236          NaN
# 181                  V179  float64   450909      921          NaN
# 182                  V180  float64   450721       84          NaN
# 183                  V181  float64   450909       25          NaN
# 184                  V182  float64   450909       84          NaN
# 185                  V183  float64   450909       42          NaN
# 186                  V184  float64   450721       17          NaN
# 187                  V185  float64   450721       32          NaN
# 188                  V186  float64   450909       39          NaN
# 189                  V187  float64   450909      215          NaN
# 190                  V188  float64   450721       31          NaN
# 191                  V189  float64   450721       31          NaN
# 192                  V190  float64   450909       43          NaN
# 193                  V191  float64   450909       22          NaN
# 194                  V192  float64   450909       45          NaN
# 195                  V193  float64   450909       38          NaN
# 196                  V194  float64   450721        8          NaN
# 197                  V195  float64   450721       17          NaN
# 198                  V196  float64   450909       39          NaN
# 199                  V197  float64   450721       15          NaN
# 200                  V198  float64   450721       22          NaN
# 201                  V199  float64   450909       46          NaN
# 202                  V200  float64   450721       46          NaN
# 203                  V201  float64   450721       56          NaN
# 204                  V202  float64   450909    10970          NaN
# 205                  V203  float64   450909    14951          NaN
# 206                  V204  float64   450909    12858          NaN
# 207                  V205  float64   450909     2240          NaN
# 208                  V206  float64   450909     1780          NaN
# 209                  V207  float64   450909     3246          NaN
# 210                  V208  float64   450721     2552          NaN
# 211                  V209  float64   450721     3451          NaN
# 212                  V210  float64   450721     2836          NaN
# 213                  V211  float64   450909     7624          NaN
# 214                  V212  float64   450909     8868          NaN
# 215                  V213  float64   450909     8317          NaN
# 216                  V214  float64   450909     2282          NaN
# 217                  V215  float64   450909     2747          NaN
# 218                  V216  float64   450909     2532          NaN
# 219                  V217  float64   460110      304          NaN
# 220                  V218  float64   460110      401          NaN
# 221                  V219  float64   460110      379          NaN
# 222                  V220  float64   449124       26          NaN
# 223                  V221  float64   449124       77          NaN
# 224                  V222  float64   449124       76          NaN
# 225                  V223  float64   460110       17          NaN
# 226                  V224  float64   460110       79          NaN
# 227                  V225  float64   460110       35          NaN
# 228                  V226  float64   460110       81          NaN
# 229                  V227  float64   449124       50          NaN
# 230                  V228  float64   460110       55          NaN
# 231                  V229  float64   460110       91          NaN
# 232                  V230  float64   460110       66          NaN
# 233                  V231  float64   460110      294          NaN
# 234                  V232  float64   460110      338          NaN
# 235                  V233  float64   460110      333          NaN
# 236                  V234  float64   449124      122          NaN
# 237                  V235  float64   460110       24          NaN
# 238                  V236  float64   460110       46          NaN
# 239                  V237  float64   460110       40          NaN
# 240                  V238  float64   449124       24          NaN
# 241                  V239  float64   449124       24          NaN
# 242                  V240  float64   460110        6          NaN
# 243                  V241  float64   460110        5          NaN
# 244                  V242  float64   460110       21          NaN
# 245                  V243  float64   460110       43          NaN
# 246                  V244  float64   460110       23          NaN
# 247                  V245  float64   449124       58          NaN
# 248                  V246  float64   460110       46          NaN
# 249                  V247  float64   460110       19          NaN
# 250                  V248  float64   460110       23          NaN
# 251                  V249  float64   460110       23          NaN
# 252                  V250  float64   449124       19          NaN
# 253                  V251  float64   449124       19          NaN
# 254                  V252  float64   460110       25          NaN
# 255                  V253  float64   460110       66          NaN
# 256                  V254  float64   460110       45          NaN
# 257                  V255  float64   449124       46          NaN
# 258                  V256  float64   449124       48          NaN
# 259                  V257  float64   460110       49          NaN
# 260                  V258  float64   460110       67          NaN
# 261                  V259  float64   449124       68          NaN
# 262                  V260  float64   460110        9          NaN
# 263                  V261  float64   460110       41          NaN
# 264                  V262  float64   460110       21          NaN
# 265                  V263  float64   460110    10422          NaN
# 266                  V264  float64   460110    13358          NaN
# 267                  V265  float64   460110    11757          NaN
# 268                  V266  float64   460110     2178          NaN
# 269                  V267  float64   460110     3616          NaN
# 270                  V268  float64   460110     2756          NaN
# 271                  V269  float64   460110      151          NaN
# 272                  V270  float64   449124     2340          NaN
# 273                  V271  float64   449124     2787          NaN
# 274                  V272  float64   449124     2507          NaN
# 275                  V273  float64   460110     7177          NaN
# 276                  V274  float64   460110     8315          NaN
# 277                  V275  float64   460110     7776          NaN
# 278                  V276  float64   460110     2263          NaN
# 279                  V277  float64   460110     2540          NaN
# 280                  V278  float64   460110     2398          NaN
# 281                  V279  float64       12      881          0.0
# 282                  V280  float64       12      975          0.0
# 283                  V282  float64     1269       33          1.0
# 284                  V283  float64     1269       62          1.0
# 285                  V285  float64       12       96          0.0
# 286                  V287  float64       12       32          0.0
# 287                  V288  float64     1269       11          0.0
# 288                  V289  float64     1269       13          0.0
# 289                  V291  float64       12      219          1.0
# 290                  V292  float64       12      173          1.0
# 291                  V294  float64       12     1286          1.0
# 292                  V302  float64       12       17          0.0
# 293                  V303  float64       12       21          0.0
# 294                  V304  float64       12       17          0.0
# 295                  V306  float64       12    16210          0.0
# 296                  V307  float64       12    37367        117.0
# 297                  V308  float64       12    23064          0.0
# 298                  V310  float64       12    19136          0.0
# 299                  V312  float64       12     8068          0.0
# 300                  V313  float64     1269     5529          0.0
# 301                  V314  float64     1269    11377          0.0
# 302                  V315  float64     1269     6973          0.0
# 303                  V317  float64       12    15184        117.0
# 304                  V322  float64   508189      881          NaN
# 305                  V323  float64   508189     1411          NaN
# 306                  V324  float64   508189      976          NaN
# 307                  V325  float64   508189       13          NaN
# 308                  V326  float64   508189       45          NaN
# 309                  V327  float64   508189       19          NaN
# 310                  V328  float64   508189       16          NaN
# 311                  V329  float64   508189      100          NaN
# 312                  V330  float64   508189       56          NaN
# 313                  V331  float64   508189     1758          NaN
# 314                  V332  float64   508189     2453          NaN
# 315                  V333  float64   508189     1971          NaN
# 316                  V334  float64   508189      143          NaN
# 317                  V335  float64   508189      672          NaN
# 318                  V336  float64   508189      356          NaN
# 319                  V337  float64   508189      254          NaN
# 320                  V338  float64   508189      380          NaN
# 321                  V339  float64   508189      334          NaN
# 322                 id_01  float64   446307       77          NaN
# 323                 id_02  float64   449668   115655          NaN
# 324                 id_03  float64   524216       24          NaN
# 325                 id_04  float64   524216       15          NaN
# 326                 id_05  float64   453675       93          NaN
# 327                 id_06  float64   453675      101          NaN
# 328                 id_09  float64   515614       46          NaN
# 329                 id_10  float64   515614       62          NaN
# 330                 id_11  float64   449562      365          NaN
# 331                 id_12    int64        0        3          2.0
# 332                 id_13    int64        0       55         55.0
# 333                 id_14    int64        0       26         28.0
# 334                 id_15    int64        0        4          3.0
# 335                 id_16    int64        0        3          2.0
# 336                 id_17    int64        0      105        127.0
# 337                 id_19    int64        0      523        568.0
# 338                 id_20    int64        0      395        547.0
# 339                 id_28    int64        0        3          2.0
# 340                 id_29    int64        0        3          2.0
# 341                 id_30    int64        0       75         86.0
# 342                 id_31    int64        0      130        145.0
# 343                 id_32    int64        0        5          6.0
# 344                 id_33    int64        0      261        461.0
# 345                 id_34    int64        0        5          4.0
# 346                 id_35    int64        0        3          2.0
# 347                 id_36    int64        0        3          2.0
# 348                 id_37    int64        0        3          2.0
# 349                 id_38    int64        0        3          2.0
# 350            DeviceType    int64        0        3          2.0
# 351            DeviceInfo    int64        0     1787       2741.0
# 352               Weekday    int64        0        7          0.0
# 353                  Hour    int64        0       24          0.0
# 354     P_emaildomain_pre    int64        0        9          6.0
# 355  P_emaildomain_suffix    int64        0        9          6.0
# 356     R_emaildomain_pre    int64        0        9          6.0
# 357  R_emaildomain_suffix    int64        0        9          6.0
#
#      Second Value  Third Value  Entropy
# 0       2987001.0    2987002.0    19.17
# 1             0.0          0.0     0.22
# 2         86401.0      86469.0    19.11
# 3            29.0         59.0     8.35
# 4             4.0          4.0     1.28
# 5          1726.0       3597.0     9.97
# 6           304.0        390.0     6.34
# 7            50.0         50.0     0.70
# 8             2.0          4.0     1.11
# 9             2.0         66.0     2.70
# 10            1.0          2.0     0.84
# 11          225.0        230.0     5.00
# 12           80.0         80.0     0.58
# 13            NaN        287.0     6.34
# 14           16.0         36.0     2.89
# 15           35.0         35.0     1.43
# 16            1.0          1.0     2.72
# 17            1.0          1.0     2.75
# 18            0.0          0.0     1.12
# 19            0.0          0.0     2.06
# 20            1.0          1.0     2.52
# 21            0.0          0.0     0.71
# 22            0.0          0.0     1.25
# 23            0.0          1.0     2.62
# 24            0.0          0.0     1.23
# 25            1.0          1.0     2.17
# 26            0.0          0.0     0.95
# 27            1.0          1.0     4.66
# 28            1.0          1.0     2.67
# 29            0.0          0.0     5.57
# 30            NaN          NaN     8.57
# 31            NaN          NaN     5.60
# 32            0.0          0.0     6.42
# 33            NaN          NaN     5.95
# 34            NaN          NaN     4.09
# 35            NaN          NaN    11.32
# 36            NaN          NaN     4.29
# 37            0.0          0.0     6.09
# 38            NaN        315.0     6.73
# 39            NaN          NaN     3.70
# 40            NaN          NaN     2.26
# 41            NaN          NaN     3.14
# 42            0.0        315.0     6.88
# 43            2.0          1.0     1.00
# 44            2.0          1.0     1.26
# 45            2.0          1.0     1.40
# 46            0.0          0.0     1.68
# 47            1.0          0.0     1.38
# 48            1.0          0.0     1.57
# 49            2.0          0.0     1.21
# 50            2.0          0.0     1.37
# 51            2.0          0.0     1.24
# 52            NaN          1.0     0.00
# 53            NaN          1.0     0.27
# 54            NaN          1.0     0.40
# 55            NaN          1.0     0.86
# 56            NaN          1.0     0.95
# 57            NaN          1.0     0.27
# 58            NaN          1.0     0.38
# 59            NaN          1.0     0.18
# 60            NaN          1.0     0.25
# 61            NaN          0.0     1.07
# 62            NaN          0.0     1.13
# 63            0.0          1.0     1.05
# 64            0.0          1.0     1.11
# 65            0.0          0.0     0.54
# 66            0.0          0.0     0.55
# 67            0.0          0.0     0.58
# 68            0.0          0.0     0.58
# 69            1.0          1.0     0.82
# 70            1.0          1.0     0.90
# 71            0.0          0.0     0.56
# 72            0.0          0.0     0.57
# 73            0.0          0.0     1.03
# 74            0.0          0.0     1.10
# 75            0.0          0.0     0.59
# 76            0.0          0.0     0.60
# 77            0.0          0.0     0.56
# 78            0.0          0.0     0.59
# 79            0.0          1.0     1.06
# 80            0.0          1.0     1.13
# 81            1.0          1.0     0.44
# 82            1.0          1.0     0.60
# 83            0.0          0.0     0.67
# 84            0.0          0.0     0.71
# 85            1.0          1.0     0.01
# 86            0.0          0.0     0.65
# 87            0.0          0.0     0.69
# 88            1.0          1.0     0.38
# 89            1.0          1.0     0.50
# 90            1.0          1.0     0.17
# 91            1.0          1.0     0.25
# 92            0.0          0.0     1.02
# 93            0.0          0.0     1.08
# 94            0.0          0.0     0.65
# 95            0.0          0.0     0.69
# 96            0.0          0.0     0.73
# 97            0.0          1.0     1.05
# 98            0.0          1.0     1.12
# 99            1.0          1.0     0.50
# 100           0.0          0.0     0.57
# 101           0.0          0.0     0.58
# 102           0.0          0.0     0.59
# 103           0.0          0.0     0.62
# 104           1.0          1.0     0.85
# 105           1.0          1.0     0.95
# 106           0.0          0.0     0.58
# 107           0.0          0.0     0.62
# 108           0.0          0.0     1.03
# 109           0.0          0.0     1.10
# 110           0.0          0.0     0.60
# 111           0.0          0.0     0.62
# 112           0.0          0.0     0.60
# 113           0.0          0.0     0.64
# 114           0.0          1.0     1.06
# 115           0.0          1.0     1.12
# 116           1.0          1.0     0.56
# 117           0.0          0.0     0.59
# 118           0.0          0.0     0.61
# 119           0.0          0.0     0.64
# 120           1.0          1.0     0.82
# 121           1.0          1.0     0.92
# 122           0.0          0.0     0.59
# 123           0.0          0.0     0.64
# 124           1.0          1.0     0.47
# 125           0.0          0.0     1.04
# 126           0.0          0.0     1.11
# 127           0.0          0.0     0.63
# 128           0.0          0.0     0.65
# 129           0.0          0.0     0.58
# 130           0.0          0.0     0.82
# 131           0.0          0.0     2.04
# 132           0.0          0.0     1.29
# 133           0.0          0.0     1.69
# 134           0.0          0.0     0.88
# 135           0.0          0.0     1.83
# 136           0.0          0.0     5.05
# 137           0.0          0.0     3.02
# 138           0.0          0.0     4.09
# 139           0.0          0.0     1.97
# 140           NaN          NaN     0.15
# 141           NaN          NaN     1.71
# 142           NaN          NaN     1.78
# 143           NaN          NaN     0.23
# 144           NaN          NaN     0.25
# 145           NaN          NaN     1.93
# 146           NaN          NaN     1.89
# 147           NaN          NaN     2.31
# 148           NaN          NaN     0.58
# 149           NaN          NaN     0.60
# 150           NaN          NaN     0.99
# 151           NaN          NaN     1.01
# 152           NaN          NaN     2.21
# 153           NaN          NaN     1.25
# 154           NaN          NaN     1.22
# 155           NaN          NaN     0.94
# 156           NaN          NaN     0.95
# 157           NaN          NaN     0.99
# 158           NaN          NaN     1.02
# 159           NaN          NaN     1.20
# 160           NaN          NaN     1.24
# 161           NaN          NaN     2.56
# 162           NaN          NaN     3.33
# 163           NaN          NaN     0.36
# 164           NaN          NaN     0.41
# 165           NaN          NaN     0.38
# 166           NaN          NaN     2.59
# 167           NaN          NaN     2.90
# 168           NaN          NaN     2.64
# 169           NaN          NaN     1.50
# 170           NaN          NaN     1.72
# 171           NaN          NaN     0.50
# 172           NaN          NaN     1.54
# 173           NaN          NaN     1.75
# 174           NaN          NaN     0.48
# 175           NaN          NaN     0.31
# 176           NaN          NaN     0.57
# 177           NaN          NaN     0.68
# 178           NaN          NaN     0.91
# 179           NaN          NaN     1.01
# 180           NaN          NaN     1.19
# 181           NaN          NaN     1.12
# 182           NaN          NaN     0.85
# 183           NaN          NaN     0.67
# 184           NaN          NaN     0.83
# 185           NaN          NaN     0.76
# 186           NaN          NaN     0.54
# 187           NaN          NaN     0.63
# 188           NaN          NaN     0.42
# 189           NaN          NaN     0.55
# 190           NaN          NaN     0.70
# 191           NaN          NaN     0.74
# 192           NaN          NaN     0.56
# 193           NaN          NaN     0.19
# 194           NaN          NaN     0.25
# 195           NaN          NaN     0.23
# 196           NaN          NaN     0.46
# 197           NaN          NaN     0.48
# 198           NaN          NaN     0.20
# 199           NaN          NaN     0.47
# 200           NaN          NaN     0.49
# 201           NaN          NaN     0.69
# 202           NaN          NaN     0.94
# 203           NaN          NaN     1.00
# 204           NaN          NaN     3.27
# 205           NaN          NaN     4.13
# 206           NaN          NaN     3.73
# 207           NaN          NaN     1.13
# 208           NaN          NaN     0.74
# 209           NaN          NaN     1.69
# 210           NaN          NaN     1.56
# 211           NaN          NaN     1.74
# 212           NaN          NaN     1.62
# 213           NaN          NaN     1.99
# 214           NaN          NaN     2.25
# 215           NaN          NaN     2.14
# 216           NaN          NaN     1.24
# 217           NaN          NaN     1.50
# 218           NaN          NaN     1.40
# 219           NaN          NaN     1.43
# 220           NaN          NaN     1.78
# 221           NaN          NaN     1.60
# 222           NaN          NaN     0.48
# 223           NaN          NaN     1.84
# 224           NaN          NaN     1.93
# 225           NaN          NaN     0.45
# 226           NaN          NaN     0.84
# 227           NaN          NaN     0.64
# 228           NaN          NaN     0.49
# 229           NaN          NaN     0.54
# 230           NaN          NaN     0.93
# 231           NaN          NaN     1.22
# 232           NaN          NaN     1.07
# 233           NaN          NaN     0.95
# 234           NaN          NaN     1.09
# 235           NaN          NaN     1.02
# 236           NaN          NaN     1.07
# 237           NaN          NaN     0.62
# 238           NaN          NaN     0.72
# 239           NaN          NaN     0.67
# 240           NaN          NaN     0.52
# 241           NaN          NaN     0.54
# 242           NaN          NaN     0.01
# 243           NaN          NaN     0.00
# 244           NaN          NaN     0.43
# 245           NaN          NaN     0.54
# 246           NaN          NaN     0.44
# 247           NaN          NaN     1.09
# 248           NaN          NaN     0.58
# 249           NaN          NaN     0.15
# 250           NaN          NaN     0.27
# 251           NaN          NaN     0.20
# 252           NaN          NaN     0.88
# 253           NaN          NaN     0.90
# 254           NaN          NaN     0.15
# 255           NaN          NaN     0.32
# 256           NaN          NaN     0.22
# 257           NaN          NaN     0.90
# 258           NaN          NaN     0.93
# 259           NaN          NaN     0.72
# 260           NaN          NaN     0.84
# 261           NaN          NaN     1.30
# 262           NaN          NaN     0.62
# 263           NaN          NaN     0.91
# 264           NaN          NaN     0.75
# 265           NaN          NaN     3.32
# 266           NaN          NaN     4.13
# 267           NaN          NaN     3.71
# 268           NaN          NaN     1.12
# 269           NaN          NaN     1.97
# 270           NaN          NaN     1.53
# 271           NaN          NaN     0.21
# 272           NaN          NaN     1.27
# 273           NaN          NaN     1.36
# 274           NaN          NaN     1.30
# 275           NaN          NaN     1.99
# 276           NaN          NaN     2.26
# 277           NaN          NaN     2.12
# 278           NaN          NaN     1.22
# 279           NaN          NaN     1.44
# 280           NaN          NaN     1.32
# 281           0.0          0.0     0.98
# 282           0.0          0.0     1.54
# 283           1.0          1.0     1.52
# 284           1.0          1.0     1.79
# 285           0.0          0.0     1.99
# 286           0.0          0.0     1.07
# 287           0.0          0.0     0.73
# 288           0.0          0.0     0.86
# 289           1.0          1.0     1.05
# 290           1.0          1.0     0.66
# 291           0.0          0.0     0.92
# 292           0.0          0.0     0.86
# 293           0.0          0.0     0.95
# 294           0.0          0.0     0.90
# 295           0.0          0.0     2.34
# 296           0.0          0.0     6.33
# 297           0.0          0.0     3.84
# 298           0.0          0.0     5.26
# 299           0.0          0.0     2.66
# 300           0.0          0.0     2.07
# 301           0.0          0.0     2.74
# 302           0.0          0.0     2.26
# 303           0.0          0.0     1.87
# 304           NaN          NaN     1.31
# 305           NaN          NaN     1.77
# 306           NaN          NaN     1.53
# 307           NaN          NaN     0.31
# 308           NaN          NaN     0.90
# 309           NaN          NaN     0.65
# 310           NaN          NaN     0.72
# 311           NaN          NaN     0.85
# 312           NaN          NaN     0.80
# 313           NaN          NaN     1.91
# 314           NaN          NaN     2.56
# 315           NaN          NaN     2.26
# 316           NaN          NaN     0.50
# 317           NaN          NaN     1.27
# 318           NaN          NaN     0.93
# 319           NaN          NaN     1.03
# 320           NaN          NaN     1.19
# 321           NaN          NaN     1.13
# 322           NaN          NaN     2.27
# 323           NaN          NaN    16.72
# 324           NaN          NaN     0.32
# 325           NaN          NaN     0.10
# 326           NaN          NaN     2.40
# 327           NaN          NaN     2.63
# 328           NaN          NaN     0.51
# 329           NaN          NaN     0.30
# 330           NaN          NaN     0.64
# 331           2.0          2.0     0.95
# 332          55.0         55.0     1.31
# 333          28.0         28.0     0.82
# 334           3.0          3.0     1.11
# 335           2.0          2.0     0.98
# 336         127.0        127.0     1.09
# 337         568.0        568.0     2.07
# 338         547.0        547.0     2.04
# 339           2.0          2.0     1.03
# 340           2.0          2.0     1.03
# 341          86.0         86.0     1.12
# 342         145.0        145.0     1.89
# 343           6.0          6.0     0.68
# 344         461.0        461.0     1.07
# 345           4.0          4.0     0.67
# 346           2.0          2.0     1.03
# 347           2.0          2.0     0.86
# 348           2.0          2.0     0.97
# 349           2.0          2.0     1.03
# 350           2.0          2.0     1.02
# 351        2741.0       2741.0     1.60
# 352           0.0          0.0     2.80
# 353           0.0          0.0     4.26
# 354           4.0          5.0     2.22
# 355           0.0          0.0     0.95
# 356           6.0          6.0     1.04
# 357           6.0          6.0     0.90

# %%
Vcols = []
for i in range(1, 340):
    col = "V"+str(i)
    if col in df_train.columns:
        print(col, df_train[col].min(), df_train[col].max(), df_train[col].nunique())
        Vcols.append(col)
# Out:
# V1 0.0 1.0 2
# V2 0.0 8.0 9
# V3 0.0 9.0 10
# V4 0.0 6.0 7
# V5 0.0 6.0 7
# V6 0.0 9.0 10
# V7 0.0 9.0 10
# V8 0.0 8.0 9
# V9 0.0 8.0 9
# V10 0.0 4.0 5
# V11 0.0 5.0 6
# V12 0.0 3.0 4
# V13 0.0 6.0 7
# V15 0.0 7.0 8
# V16 0.0 15.0 15
# V17 0.0 15.0 16
# V18 0.0 15.0 16
# V19 0.0 7.0 8
# V20 0.0 15.0 15
# V21 0.0 5.0 6
# V22 0.0 8.0 9
# V29 0.0 5.0 6
# V30 0.0 9.0 8
# V31 0.0 7.0 8
# V32 0.0 15.0 15
# V33 0.0 7.0 7
# V34 0.0 13.0 13
# V35 0.0 3.0 4
# V36 0.0 5.0 6
# V37 0.0 54.0 55
# V38 0.0 54.0 55
# V39 0.0 15.0 16
# V40 0.0 24.0 18
# V41 0.0 1.0 2
# V42 0.0 8.0 9
# V43 0.0 8.0 9
# V44 0.0 48.0 49
# V45 0.0 48.0 49
# V46 0.0 6.0 7
# V47 0.0 12.0 9
# V48 0.0 5.0 6
# V49 0.0 5.0 6
# V50 0.0 5.0 6
# V51 0.0 6.0 7
# V52 0.0 12.0 9
# V53 0.0 5.0 6
# V54 0.0 6.0 7
# V56 0.0 51.0 52
# V57 0.0 6.0 7
# V58 0.0 10.0 11
# V59 0.0 16.0 17
# V60 0.0 16.0 17
# V61 0.0 6.0 7
# V62 0.0 10.0 11
# V63 0.0 7.0 8
# V64 0.0 7.0 8
# V69 0.0 5.0 6
# V70 0.0 6.0 7
# V71 0.0 6.0 7
# V72 0.0 10.0 11
# V73 0.0 7.0 8
# V74 0.0 8.0 9
# V75 0.0 4.0 5
# V76 0.0 6.0 7
# V78 0.0 31.0 32
# V79 0.0 7.0 8
# V80 0.0 19.0 20
# V81 0.0 19.0 20
# V82 0.0 7.0 8
# V83 0.0 7.0 8
# V84 0.0 7.0 8
# V85 0.0 7.0 8
# V87 0.0 30.0 31
# V90 0.0 5.0 6
# V91 0.0 6.0 7
# V92 0.0 7.0 8
# V93 0.0 7.0 8
# V94 0.0 2.0 3
# V95 0.0 880.0 881
# V96 0.0 1410.0 1410
# V97 0.0 976.0 976
# V99 0.0 88.0 89
# V100 0.0 28.0 29
# V126 0.0 160000.0 10299
# V127 0.0 160000.0 24414
# V128 0.0 160000.0 14507
# V130 0.0 55125.0 12332
# V131 0.0 55125.0 4444
# V138 0.0 22.0 23
# V139 0.0 33.0 34
# V140 0.0 33.0 34
# V141 0.0 5.0 6
# V142 0.0 9.0 10
# V143 0.0 869.0 870
# V144 0.0 62.0 63
# V145 0.0 297.0 260
# V146 0.0 24.0 25
# V147 0.0 26.0 27
# V148 0.0 20.0 21
# V149 0.0 20.0 21
# V150 1.0 3389.0 1996
# V151 1.0 57.0 56
# V152 1.0 69.0 39
# V153 0.0 18.0 19
# V154 0.0 18.0 19
# V155 0.0 24.0 25
# V156 0.0 24.0 25
# V157 0.0 24.0 25
# V158 0.0 24.0 25
# V159 0.0 55125.0 6663
# V160 0.0 641511.4375 9621
# V161 0.0 3300.0 79
# V162 0.0 3300.0 185
# V163 0.0 3300.0 106
# V164 0.0 93736.0 1978
# V165 0.0 98476.0 2547
# V166 0.0 104060.0 987
# V167 0.0 872.0 873
# V168 0.0 964.0 965
# V169 0.0 19.0 20
# V170 0.0 48.0 49
# V171 0.0 61.0 62
# V172 0.0 31.0 32
# V173 0.0 7.0 8
# V174 0.0 8.0 9
# V175 0.0 14.0 15
# V176 0.0 48.0 49
# V177 0.0 861.0 862
# V178 0.0 1235.0 1236
# V179 0.0 920.0 921
# V180 0.0 83.0 84
# V181 0.0 24.0 25
# V182 0.0 83.0 84
# V183 0.0 41.0 42
# V184 0.0 16.0 17
# V185 0.0 31.0 32
# V186 0.0 38.0 39
# V187 0.0 218.0 215
# V188 0.0 30.0 31
# V189 0.0 30.0 31
# V190 0.0 42.0 43
# V191 0.0 21.0 22
# V192 0.0 44.0 45
# V193 0.0 37.0 38
# V194 0.0 7.0 8
# V195 0.0 16.0 17
# V196 0.0 38.0 39
# V197 0.0 14.0 15
# V198 0.0 21.0 22
# V199 0.0 45.0 46
# V200 0.0 45.0 46
# V201 0.0 55.0 56
# V202 0.0 104060.0 10970
# V203 0.0 139777.0 14951
# V204 0.0 104060.0 12858
# V205 0.0 55125.0 2240
# V206 0.0 55125.0 1780
# V207 0.0 55125.0 3246
# V208 0.0 3300.0 2552
# V209 0.0 8050.0 3451
# V210 0.0 3300.0 2836
# V211 0.0 92888.0 7624
# V212 0.0 129006.0 8868
# V213 0.0 97628.0 8317
# V214 0.0 104060.0 2282
# V215 0.0 104060.0 2747
# V216 0.0 104060.0 2532
# V217 0.0 303.0 304
# V218 0.0 400.0 401
# V219 0.0 378.0 379
# V220 0.0 25.0 26
# V221 0.0 384.0 77
# V222 0.0 384.0 76
# V223 0.0 16.0 17
# V224 0.0 144.0 79
# V225 0.0 51.0 35
# V226 0.0 242.0 81
# V227 0.0 360.0 50
# V228 0.0 54.0 55
# V229 0.0 176.0 91
# V230 0.0 65.0 66
# V231 0.0 293.0 294
# V232 0.0 337.0 338
# V233 0.0 332.0 333
# V234 0.0 121.0 122
# V235 0.0 23.0 24
# V236 0.0 45.0 46
# V237 0.0 39.0 40
# V238 0.0 23.0 24
# V239 0.0 23.0 24
# V240 0.0 7.0 6
# V241 0.0 5.0 5
# V242 0.0 20.0 21
# V243 0.0 57.0 43
# V244 0.0 22.0 23
# V245 0.0 262.0 58
# V246 0.0 45.0 46
# V247 0.0 18.0 19
# V248 0.0 36.0 23
# V249 0.0 22.0 23
# V250 0.0 18.0 19
# V251 0.0 18.0 19
# V252 0.0 24.0 25
# V253 0.0 163.0 66
# V254 0.0 60.0 45
# V255 0.0 87.0 46
# V256 0.0 87.0 48
# V257 0.0 48.0 49
# V258 0.0 66.0 67
# V259 0.0 285.0 68
# V260 0.0 8.0 9
# V261 0.0 49.0 41
# V262 0.0 20.0 21
# V263 0.0 153600.0 10422
# V264 0.0 153600.0 13358
# V265 0.0 153600.0 11757
# V266 0.0 55125.0 2178
# V267 0.0 55125.0 3616
# V268 0.0 55125.0 2756
# V269 0.0 55125.0 151
# V270 0.0 4000.0 2340
# V271 0.0 4000.0 2787
# V272 0.0 4000.0 2507
# V273 0.0 51200.0 7177
# V274 0.0 66000.0 8315
# V275 0.0 51200.0 7776
# V276 0.0 104060.0 2263
# V277 0.0 104060.0 2540
# V278 0.0 104060.0 2398
# V279 0.0 880.0 881
# V280 0.0 975.0 975
# V282 0.0 32.0 33
# V283 0.0 68.0 62
# V285 0.0 95.0 96
# V287 0.0 31.0 32
# V288 0.0 10.0 11
# V289 0.0 12.0 13
# V291 1.0 1055.0 219
# V292 1.0 323.0 173
# V294 0.0 1286.0 1286
# V302 0.0 16.0 17
# V303 0.0 20.0 21
# V304 0.0 16.0 17
# V306 0.0 108800.0 16210
# V307 0.0 145765.0 37367
# V308 0.0 108800.0 23064
# V310 0.0 55125.0 19136
# V312 0.0 55125.0 8068
# V313 0.0 4817.47021484375 5529
# V314 0.0 7519.8701171875 11377
# V315 0.0 4817.47021484375 6973
# V317 0.0 134021.0 15184
# V322 0.0 880.0 881
# V323 0.0 1411.0 1411
# V324 0.0 976.0 976
# V325 0.0 12.0 13
# V326 0.0 44.0 45
# V327 0.0 18.0 19
# V328 0.0 15.0 16
# V329 0.0 99.0 100
# V330 0.0 55.0 56
# V331 0.0 160000.0 1758
# V332 0.0 160000.0 2453
# V333 0.0 160000.0 1971
# V334 0.0 55125.0 143
# V335 0.0 55125.0 672
# V336 0.0 55125.0 356
# V337 0.0 104060.0 254
# V338 0.0 104060.0 380
# V339 0.0 104060.0 334

# %%
# Shape before applying PCA on V features
Y_train = df_train["isFraud"]

# %%
del df_train["isFraud"]

# %%
df_test.shape
# Out:
# (506691, 357)

# %%
df = pd.concat([df_train, df_test], axis=0, join='outer')
df = df.reset_index()
df.index.nunique()
# Out:
# 1097231

# %%
df_train.describe()

# %%
Vcols

# %%
# scaler = StandardScaler()
# scaler.fit(df)
# scaled_df = scaler.transform(df)

# %%
# Don't think fillna -999 will work well with PCA

for col in Vcols:
    df[col].fillna((df[col].min() - 2), inplace=True)
    df[col] = (minmax_scale(df[col], feature_range=(0,1)))  
    
df = PCA_change(df, Vcols, prefix='PCA_V_', n_components=20)

# %%
df.shape
# Out:
# (1097231, 138)

# %%
df.columns[49:]
# Out:
# Index(['M7', 'M8', 'M9', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06',
#        'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16',
#        'id_17', 'id_19', 'id_20', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32',
#        'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'DeviceType',
#        'DeviceInfo', 'Weekday', 'Hour', 'P_emaildomain_pre',
#        'P_emaildomain_suffix', 'R_emaildomain_pre', 'R_emaildomain_suffix',
#        'PCA_V_0', 'PCA_V_1', 'PCA_V_2', 'PCA_V_3', 'PCA_V_4', 'PCA_V_5',
#        'PCA_V_6', 'PCA_V_7', 'PCA_V_8', 'PCA_V_9', 'PCA_V_10', 'PCA_V_11',
#        'PCA_V_12', 'PCA_V_13', 'PCA_V_14', 'PCA_V_15', 'PCA_V_16', 'PCA_V_17',
#        'PCA_V_18', 'PCA_V_19', 'PCA_V_20', 'PCA_V_21', 'PCA_V_22', 'PCA_V_23',
#        'PCA_V_24', 'PCA_V_25', 'PCA_V_26', 'PCA_V_27', 'PCA_V_28', 'PCA_V_29',
#        'PCA_V_30', 'PCA_V_31', 'PCA_V_32', 'PCA_V_33', 'PCA_V_34', 'PCA_V_35',
#        'PCA_V_36', 'PCA_V_37', 'PCA_V_38', 'PCA_V_39', 'PCA_V_40', 'PCA_V_41',
#        'PCA_V_42', 'PCA_V_43', 'PCA_V_44', 'PCA_V_45', 'PCA_V_46', 'PCA_V_47',
#        'PCA_V_48', 'PCA_V_49'],
#       dtype='object')

# %%
# PCA_V_0 -> PCA_V_49 are the principle component numerical feature gained from V1 -> V339

# %%
resumetable(df)

# %%
for i in range(20):
    col = "PCA_V_"+str(i)
    print(df[col].min(), df[col].max())
# Out:
# -1.4876244007205415 3.0224910544208186
# -1.57091011826102 1.6600664937349912
# -1.432804619046758 1.6049815284204236
# -1.0090182160507601 1.5035245783165827
# -0.34964254241239 1.9001702232259705
# -0.6412966306185496 1.4899044642708217
# -0.5774155052433373 1.2688976926847366
# -0.9407515837709304 1.9062248361766165
# -0.6104628548955201 1.57664180894089
# -0.8087371608109933 2.6516030666497628
# -0.8306737417371701 0.8749566851789861
# -1.0991492383234749 1.3263383173841365
# -0.9377741454689686 1.1071653611806145
# -0.5294843939267786 0.6960828347438942
# -0.5005806031783805 0.6152069498336044
# -0.7295294074065196 1.1470850714863163
# -0.4416473165740634 0.719193809640908
# -0.5564454975345979 2.5674587375740296
# -0.35926966549379635 0.6217762278649104
# -0.27918982467377385 0.49253750604755664
# -0.8162260808889967 1.618971362729274
# -0.41139653877688853 0.6763643248374142
# -0.42353975674507804 0.5630220811804209
# -0.7099232507848598 1.0301263289829279
# -1.1859164493933134 1.3328351166942172
# -0.5325582109314011 0.8937886477131344
# -0.6392548807126479 1.048043242851717
# -0.7544527892009516 1.0019638750760158
# -0.7559019247885961 1.0124147166764346
# -0.765295949590193 1.2594748873737436
# -0.6003161982486925 0.7292261126343089
# -0.43352236928062904 0.5275169336097414
# -0.5920807589793146 1.319707561464765
# -0.4518980752094175 1.0985826783858355
# -0.5721251095932824 1.1779204497437012
# -0.34096096614735083 0.3580484169080302
# -0.6439283406003043 0.6774407359941708
# -0.48603733643632097 0.6254093735906069
# -0.6084346838416861 0.7628455642332088
# -0.40060422383811484 0.6662009014329049
# -0.3770283764824429 0.5899797972044746
# -0.953030083264532 1.02273055513722
# -0.49922226001729625 0.9121826839918201
# -0.5833505839310817 0.5982169190170531
# -0.5267904098555481 0.5733018324183377
# -0.3291656502050197 1.0247474569324184
# -0.5595455040038865 0.5688164437845356
# -0.4492266076058375 0.5536859233089706
# -0.38507755976974445 0.8487351076982406
# -0.6569118773616632 0.7133439955057197

# %%
R_domain_probability = df_train.groupby(['R_emaildomain'])["isFraud"].mean()
df_train.groupby(df_train["R_emaildomain"].isnull())["isFraud"].mean()

# %%
df["R_emaildomain_factor"] = np.where((df["R_emaildomain"].isnull()), 0.020819, 0.081775)

P_domain_probability = df_train.groupby(['P_emaildomain'])['isFraud'].mean()
p = P_domain_probability.to_dict()
df["P_emaildomain_factor"] = df['P_emaildomain'].map(p).fillna(0.029538)
# df_train["P_emaildomain_factor"] = df_transaction_train['P_emaildomain'].map(p).fillna(0.029538)
# df_test["P_emaildomain_factor"] = df_transaction_test["P_emaildomain"].map(p).fillna(0.029538)

# %%
numerical = ["TransactionAmt", "dist1"] + ["C" + str(i) for i in range(1, 15)] + \
            ["D" + str(i) for i in range(1, 16)] + ["PCA_V_"+str(i) for i in range(20)] + \
            ['id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_09', 'id_10', 'id_11']
numerical.remove("C3")
numerical.remove("D7")

# %%
print(df.shape)
print(len(categorical)+len(numerical))
# Out:
# (1097231, 138)
# 135

# %%
df = reduce_mem_usage(df)
# Out:
# Mem. usage decreased to 196.72 Mb (78.2% reduction)

# %%
for col in numerical:
    print(col, df[col].min(), df[col].max())
# Out:
# TransactionAmt 0.018 31940.0
# dist1 0.0 10290.0
# C1 0.0 4684.0
# C2 0.0 5692.0
# C4 0.0 2252.0
# C5 0.0 376.0
# C6 0.0 2252.0
# C7 0.0 2256.0
# C8 0.0 3332.0
# C9 0.0 572.0
# C10 0.0 3256.0
# C11 0.0 3188.0
# C12 0.0 3188.0
# C13 0.0 2918.0
# C14 0.0 1429.0
# D1 0.0 641.0
# D2 0.0 641.0
# D3 0.0 1076.0
# D4 -122.0 1091.0
# D5 0.0 1088.0
# D6 -83.0 1091.0
# D8 0.0 2030.0
# D9 0.0 0.9585
# D10 0.0 1091.0
# D11 -53.0 883.0
# D12 -83.0 879.0
# D13 0.0 1066.0
# D14 -193.0 1085.0
# D15 -83.0 1091.0
# PCA_V_0 -1.487 3.023
# PCA_V_1 -1.571 1.66
# PCA_V_2 -1.433 1.605
# PCA_V_3 -1.009 1.504
# PCA_V_4 -0.3496 1.9
# PCA_V_5 -0.641 1.49
# PCA_V_6 -0.5776 1.269
# PCA_V_7 -0.941 1.906
# PCA_V_8 -0.6104 1.576
# PCA_V_9 -0.8086 2.652
# PCA_V_10 -0.8306 0.875
# PCA_V_11 -1.1 1.326
# PCA_V_12 -0.938 1.107
# PCA_V_13 -0.5293 0.6963
# PCA_V_14 -0.5005 0.615
# PCA_V_15 -0.7295 1.147
# PCA_V_16 -0.4417 0.719
# PCA_V_17 -0.5566 2.568
# PCA_V_18 -0.3594 0.6216
# PCA_V_19 -0.2793 0.4924
# PCA_V_20 -0.8164 1.619
# PCA_V_21 -0.4114 0.6763
# PCA_V_22 -0.4236 0.563
# PCA_V_23 -0.71 1.03
# PCA_V_24 -1.186 1.333
# PCA_V_25 -0.5327 0.8936
# PCA_V_26 -0.639 1.048
# PCA_V_27 -0.7544 1.002
# PCA_V_28 -0.756 1.013
# PCA_V_29 -0.765 1.26
# PCA_V_30 -0.6 0.729
# PCA_V_31 -0.4336 0.5273
# PCA_V_32 -0.5923 1.319
# PCA_V_33 -0.452 1.099
# PCA_V_34 -0.5723 1.178
# PCA_V_35 -0.341 0.3582
# PCA_V_36 -0.644 0.6772
# PCA_V_37 -0.486 0.6255
# PCA_V_38 -0.6084 0.7627
# PCA_V_39 -0.4006 0.666
# PCA_V_40 -0.377 0.59
# PCA_V_41 -0.953 1.022
# PCA_V_42 -0.4993 0.912
# PCA_V_43 -0.5835 0.598
# PCA_V_44 -0.527 0.573
# PCA_V_45 -0.329 1.024
# PCA_V_46 -0.5596 0.569
# PCA_V_47 -0.4492 0.5537
# PCA_V_48 -0.385 0.8486
# PCA_V_49 -0.6567 0.7134
# id_01 -100.0 0.0
# id_02 1.0 999869.0
# id_03 -13.0 11.0
# id_04 -28.0 0.0
# id_05 -81.0 52.0
# id_06 -100.0 0.0
# id_09 -36.0 25.0
# id_10 -100.0 0.0
# id_11 90.0 100.0

# %%
for col in numerical:
    if df[col].isnull().sum()>0:
        df[col] = df[col].fillna(df_train[col].mean())

# %%
for col in categorical:
    print(col, df[col].dtype)

# %%
# for col in categorical:
category_counts = {}
for col in categorical:
    df[col] = df[col].replace("nan", "other")
    df[col] = df[col].replace(np.nan, "other")
    
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(df[col].values))
    
    df[col] = lbl.transform(list(df[col].values))
    category_counts[col] = len(list(lbl.classes_)) + 1

# %%
category_counts
# Out:
# {'ProductCD': 6,
#  'card1': 17092,
#  'card2': 503,
#  'card3': 135,
#  'card4': 6,
#  'card5': 140,
#  'card6': 6,
#  'addr1': 443,
#  'addr2': 95,
#  'P_emaildomain': 62,
#  'R_emaildomain': 62,
#  'M1': 4,
#  'M2': 4,
#  'M3': 4,
#  'M4': 5,
#  'M5': 4,
#  'M6': 4,
#  'M7': 4,
#  'M8': 4,
#  'M9': 4,
#  'DeviceType': 4,
#  'DeviceInfo': 2801,
#  'Weekday': 8,
#  'Hour': 25,
#  'P_emaildomain_pre': 10,
#  'P_emaildomain_suffix': 10,
#  'R_emaildomain_pre': 10,
#  'R_emaildomain_suffix': 10,
#  'id_12': 4,
#  'id_13': 57,
#  'id_14': 30,
#  'id_15': 5,
#  'id_16': 4,
#  'id_17': 129,
#  'id_19': 570,
#  'id_20': 549,
#  'id_28': 4,
#  'id_29': 4,
#  'id_30': 88,
#  'id_31': 173,
#  'id_32': 8,
#  'id_33': 463,
#  'id_34': 6,
#  'id_35': 4,
#  'id_36': 4,
#  'id_37': 4,
#  'id_38': 4}

# %%
for col in numerical:
    scaler = StandardScaler()
    if df[col].max() > 100 and df[col].min() >= 0:
        df[col] = np.log1p(df[col])
    scaler.fit(df[col].values.reshape(-1,1))
    df[col] = scaler.transform(df[col].values.reshape(-1,1))
# Out:
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)
# /Users/ic3scar/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1508: RuntimeWarning: overflow encountered in multiply
#   sqr = np.multiply(arr, arr, out=arr)

# %%
resumetable(df)
# Out:
# Dataset Shape: (1097231, 138)
#                      Name   dtypes  Missing  Uniques   First Value  \
# 0                   index    int32        0   590540  0.000000e+00
# 1           TransactionID    int32        0  1097231  2.987000e+06
# 2           TransactionDT    int32        0  1068035  8.640000e+04
# 3          TransactionAmt  float16        0     2523 -1.348877e-01
# 4               ProductCD     int8        0        5  4.000000e+00
# 5                   card1    int16        0    17091  1.269600e+04
# 6                   card2    int16        0      502  5.010000e+02
# 7                   card3    int16        0      134  5.000000e+01
# 8                   card4     int8        0        5  1.000000e+00
# 9                   card5    int16        0      139  4.200000e+01
# 10                  card6     int8        0        5  1.000000e+00
# 11                  addr1    int16        0      442  2.150000e+02
# 12                  addr2     int8        0       94  8.000000e+01
# 13                  dist1  float16        0      943 -5.229492e-01
# 14          P_emaildomain     int8        0       61  3.500000e+01
# 15          R_emaildomain     int8        0       61  3.500000e+01
# 16                     C1  float16        0      841 -5.361328e-01
# 17                     C2  float16        0      821 -5.439453e-01
# 18                     C4  float16        0      647 -4.106445e-01
# 19                     C5  float16        0      338 -4.926758e-01
# 20                     C6  float16        0      738 -3.518066e-01
# 21                     C7  float16        0      660 -2.687988e-01
# 22                     C8  float16        0      634 -4.233398e-01
# 23                     C9  float16        0      329 -1.199341e-01
# 24                    C10  float16        0      623 -4.143066e-01
# 25                    C11  float16        0      798  5.664062e-02
# 26                    C12  float16        0      692 -3.842773e-01
# 27                    C13  float16        0      765 -7.641602e-01
# 28                    C14  float16        0      651 -4.189453e-01
# 29                     D1  float16        0      492  1.268311e-01
# 30                     D2  float16        0      491  3.474121e-01
# 31                     D3  float16        0      599 -1.542664e-02
# 32                     D4  float16        0        1 -0.000000e+00
# 33                     D5  float16        0      617  5.053711e-01
# 34                     D6  float16        0        1 -0.000000e+00
# 35                     D8  float16        0     1794  2.247314e-01
# 36                     D9  float16        0       25  4.074097e-03
# 37                    D10  float16        0      627 -8.557129e-02
# 38                    D11  float16        0        1 -0.000000e+00
# 39                    D12  float16        0        1 -0.000000e+00
# 40                    D13  float16        0      603  3.657227e-01
# 41                    D14  float16        0        1 -0.000000e+00
# 42                    D15  float16        0        1 -0.000000e+00
# 43                     M1     int8        0        3  1.000000e+00
# 44                     M2     int8        0        3  1.000000e+00
# 45                     M3     int8        0        3  1.000000e+00
# 46                     M4     int8        0        4  2.000000e+00
# 47                     M5     int8        0        3  0.000000e+00
# 48                     M6     int8        0        3  1.000000e+00
# 49                     M7     int8        0        3  2.000000e+00
# 50                     M8     int8        0        3  2.000000e+00
# 51                     M9     int8        0        3  2.000000e+00
# 52                  id_01  float16        0       90  2.020264e-02
# 53                  id_02  float32        0   198052  1.791066e-01
# 54                  id_03  float16        0       26  1.940727e-03
# 55                  id_04  float16        0       17  6.420135e-03
# 56                  id_05  float16        0       98  1.760864e-02
# 57                  id_06  float16        0      102  1.585007e-03
# 58                  id_09  float16        0       52  2.719879e-03
# 59                  id_10  float16        0       68 -4.077911e-03
# 60                  id_11  float16        0      149  8.254051e-04
# 61                  id_12     int8        0        3  2.000000e+00
# 62                  id_13     int8        0       56  5.500000e+01
# 63                  id_14     int8        0       29  2.800000e+01
# 64                  id_15     int8        0        4  3.000000e+00
# 65                  id_16     int8        0        3  2.000000e+00
# 66                  id_17    int16        0      128  1.270000e+02
# 67                  id_19    int16        0      569  5.680000e+02
# 68                  id_20    int16        0      548  5.470000e+02
# 69                  id_28     int8        0        3  2.000000e+00
# 70                  id_29     int8        0        3  2.000000e+00
# 71                  id_30     int8        0       87  8.600000e+01
# 72                  id_31    int16        0      172  1.450000e+02
# 73                  id_32     int8        0        7  6.000000e+00
# 74                  id_33    int16        0      462  4.610000e+02
# 75                  id_34     int8        0        5  4.000000e+00
# 76                  id_35     int8        0        3  2.000000e+00
# 77                  id_36     int8        0        3  2.000000e+00
# 78                  id_37     int8        0        3  2.000000e+00
# 79                  id_38     int8        0        3  2.000000e+00
# 80             DeviceType     int8        0        3  2.000000e+00
# 81             DeviceInfo    int16        0     2800  2.741000e+03
# 82                Weekday     int8        0        7  0.000000e+00
# 83                   Hour     int8        0       24  0.000000e+00
# 84      P_emaildomain_pre     int8        0        9  6.000000e+00
# 85   P_emaildomain_suffix     int8        0        9  6.000000e+00
# 86      R_emaildomain_pre     int8        0        9  6.000000e+00
# 87   R_emaildomain_suffix     int8        0        9  6.000000e+00
# 88                PCA_V_0  float16        0    14897 -3.195190e-02
# 89                PCA_V_1  float16        0    12565  1.772461e+00
# 90                PCA_V_2  float16        0    10460 -1.578125e+00
# 91                PCA_V_3  float16        0    21985  9.189453e-01
# 92                PCA_V_4  float16        0    18845  1.841736e-02
# 93                PCA_V_5  float16        0    13418 -1.081055e+00
# 94                PCA_V_6  float16        0    20135  2.161865e-01
# 95                PCA_V_7  float16        0    24429 -1.188354e-01
# 96                PCA_V_8  float16        0    19071  1.043701e-01
# 97                PCA_V_9  float16        0    19954 -5.791016e-01
# 98               PCA_V_10  float16        0    20024  2.066040e-02
# 99               PCA_V_11  float16        0    22410  1.391602e-01
# 100              PCA_V_12  float16        0    22525 -2.492676e-01
# 101              PCA_V_13  float16        0    21005  1.101562e+00
# 102              PCA_V_14  float16        0    19494  7.343750e-01
# 103              PCA_V_15  float16        0    20684 -3.344727e-01
# 104              PCA_V_16  float16        0    19705  1.182861e-01
# 105              PCA_V_17  float16        0    21608 -3.605957e-01
# 106              PCA_V_18  float16        0    19827  2.351074e-01
# 107              PCA_V_19  float16        0    20437 -6.503906e-01
# 108              PCA_V_20  float16        0    21956  1.798096e-01
# 109              PCA_V_21  float16        0    19601  3.222656e-01
# 110              PCA_V_22  float16        0    20549  2.085938e+00
# 111              PCA_V_23  float16        0    20116 -1.093140e-01
# 112              PCA_V_24  float16        0    24155  3.051758e-01
# 113              PCA_V_25  float16        0    23384 -1.024414e+00
# 114              PCA_V_26  float16        0    25228 -6.962891e-01
# 115              PCA_V_27  float16        0    22693  1.136719e+00
# 116              PCA_V_28  float16        0    23584 -1.747070e+00
# 117              PCA_V_29  float16        0    22390 -9.584961e-01
# 118              PCA_V_30  float16        0    22110  1.854492e+00
# 119              PCA_V_31  float16        0    21355 -4.722595e-03
# 120              PCA_V_32  float16        0    21813 -2.276611e-01
# 121              PCA_V_33  float16        0    21039  2.536621e-01
# 122              PCA_V_34  float16        0    22335  2.178955e-01
# 123              PCA_V_35  float16        0    20898 -1.366211e+00
# 124              PCA_V_36  float16        0    20822  3.151855e-01
# 125              PCA_V_37  float16        0    19302  1.182617e+00
# 126              PCA_V_38  float16        0    20548 -1.114258e+00
# 127              PCA_V_39  float16        0    19976 -1.012695e+00
# 128              PCA_V_40  float16        0    20719  7.495117e-01
# 129              PCA_V_41  float16        0    21555  6.049805e-01
# 130              PCA_V_42  float16        0    21437 -1.922607e-01
# 131              PCA_V_43  float16        0    21507 -5.761719e-01
# 132              PCA_V_44  float16        0    21566 -6.416016e-01
# 133              PCA_V_45  float16        0    21623  5.703125e-01
# 134              PCA_V_46  float16        0    22723 -6.967773e-01
# 135              PCA_V_47  float16        0    22244 -1.057617e+00
# 136              PCA_V_48  float16        0    22512 -6.386719e-01
# 137              PCA_V_49  float16        0    22435  8.769531e-01
#
#      Second Value   Third Value  Entropy
# 0    1.000000e+00  2.000000e+00    19.14
# 1    2.987001e+06  2.987002e+06    20.07
# 2    8.640100e+04  8.646900e+04    20.01
# 3   -1.019531e+00 -2.907715e-01     7.66
# 4    4.000000e+00  4.000000e+00     1.32
# 5    1.726000e+03  3.597000e+03    10.01
# 6    3.040000e+02  3.900000e+02     6.33
# 7    5.000000e+01  5.000000e+01     0.78
# 8    2.000000e+00  4.000000e+00     1.11
# 9    2.000000e+00  6.600000e+01     2.70
# 10   1.000000e+00  2.000000e+00     0.84
# 11   2.250000e+02  2.300000e+02     5.00
# 12   8.000000e+01  8.000000e+01     0.61
# 13   5.908203e-01  1.137695e+00     3.49
# 14   1.600000e+01  3.600000e+01     2.88
# 15   3.500000e+01  3.500000e+01     1.49
# 16  -5.361328e-01 -5.361328e-01     2.70
# 17  -5.439453e-01 -5.439453e-01     2.75
# 18  -4.106445e-01 -4.106445e-01     1.16
# 19  -4.926758e-01 -4.926758e-01     2.00
# 20  -3.518066e-01 -3.518066e-01     2.50
# 21  -2.687988e-01 -2.687988e-01     0.76
# 22  -4.233398e-01 -4.233398e-01     1.30
# 23  -8.852539e-01 -1.199341e-01     2.62
# 24  -4.143066e-01 -4.143066e-01     1.30
# 25  -4.167480e-01 -4.167480e-01     2.11
# 26  -3.842773e-01 -3.842773e-01     1.10
# 27  -7.641602e-01 -7.641602e-01     4.64
# 28  -4.189453e-01 -4.189453e-01     2.61
# 29  -9.614258e-01 -9.614258e-01     5.55
# 30   3.474121e-01  3.474121e-01     5.43
# 31   5.180664e-01  5.180664e-01     4.20
# 32  -0.000000e+00 -0.000000e+00     0.00
# 33   5.053711e-01  5.053711e-01     4.03
# 34  -0.000000e+00 -0.000000e+00     0.00
# 35   2.247314e-01  2.247314e-01     1.89
# 36   4.074097e-03  4.074097e-03     1.16
# 37  -1.097656e+00 -1.097656e+00     5.84
# 38  -0.000000e+00  0.000000e+00     0.00
# 39  -0.000000e+00 -0.000000e+00     0.00
# 40   3.657227e-01  3.657227e-01     1.01
# 41  -0.000000e+00 -0.000000e+00     0.00
# 42  -0.000000e+00  0.000000e+00     0.00
# 43   2.000000e+00  1.000000e+00     0.98
# 44   2.000000e+00  1.000000e+00     1.24
# 45   2.000000e+00  1.000000e+00     1.41
# 46   0.000000e+00  0.000000e+00     1.70
# 47   1.000000e+00  0.000000e+00     1.37
# 48   1.000000e+00  0.000000e+00     1.58
# 49   2.000000e+00  0.000000e+00     1.27
# 50   2.000000e+00  0.000000e+00     1.45
# 51   2.000000e+00  0.000000e+00     1.28
# 52   2.020264e-02  2.020264e-02     1.43
# 53   1.791066e-01  1.791066e-01     5.23
# 54   1.940727e-03  1.940727e-03     0.57
# 55   6.420135e-03  6.420135e-03     0.55
# 56   1.760864e-02  1.760864e-02     1.41
# 57   1.585007e-03  1.585007e-03     1.48
# 58   2.719879e-03  2.719879e-03     0.64
# 59  -4.077911e-03 -4.077911e-03     0.61
# 60   8.254051e-04  8.254051e-04     0.97
# 61   2.000000e+00  2.000000e+00     0.99
# 62   5.500000e+01  5.500000e+01     1.36
# 63   2.800000e+01  2.800000e+01     0.83
# 64   3.000000e+00  3.000000e+00     1.15
# 65   2.000000e+00  2.000000e+00     1.01
# 66   1.270000e+02  1.270000e+02     1.14
# 67   5.680000e+02  5.680000e+02     2.18
# 68   5.470000e+02  5.470000e+02     2.19
# 69   2.000000e+00  2.000000e+00     1.07
# 70   2.000000e+00  2.000000e+00     1.07
# 71   8.600000e+01  8.600000e+01     1.17
# 72   1.450000e+02  1.450000e+02     2.20
# 73   6.000000e+00  6.000000e+00     0.69
# 74   4.610000e+02  4.610000e+02     1.15
# 75   4.000000e+00  4.000000e+00     0.65
# 76   2.000000e+00  2.000000e+00     1.07
# 77   2.000000e+00  2.000000e+00     0.88
# 78   2.000000e+00  2.000000e+00     1.01
# 79   2.000000e+00  2.000000e+00     1.06
# 80   2.000000e+00  2.000000e+00     1.07
# 81   2.741000e+03  2.741000e+03     1.76
# 82   0.000000e+00  0.000000e+00     2.80
# 83   0.000000e+00  0.000000e+00     4.26
# 84   4.000000e+00  5.000000e+00     2.21
# 85   0.000000e+00  0.000000e+00     0.93
# 86   6.000000e+00  6.000000e+00     1.09
# 87   6.000000e+00  6.000000e+00     0.93
# 88   4.116211e-01 -7.924805e-01     9.44
# 89  -8.574219e-01  1.289062e-01     9.60
# 90  -4.946289e-01  5.209961e-01     9.86
# 91  -1.934570e+00 -1.196289e-02    10.51
# 92  -7.360840e-02 -2.136230e-01    10.59
# 93  -4.323730e-01 -1.131836e+00    10.28
# 94  -6.601562e-01  4.318848e-01    10.91
# 95  -3.708496e-01 -4.742432e-02    11.31
# 96   9.047852e-01 -1.622314e-01    10.92
# 97  -5.961914e-01 -1.401367e-01    11.12
# 98  -4.289551e-01 -8.026123e-02    11.08
# 99  -5.634766e-01  2.482910e-01    11.16
# 100 -2.414551e-01 -5.756836e-01    11.14
# 101  4.030762e-01  3.205566e-01    11.20
# 102  2.583008e-01 -1.361084e-01    11.21
# 103 -2.359619e-01 -2.333984e-01    11.22
# 104 -1.838379e-01 -3.164062e-01    11.25
# 105 -4.437256e-02  2.926636e-02    11.22
# 106  3.830566e-01  1.422119e-01    11.11
# 107 -1.667480e-01 -1.447754e-01    11.19
# 108 -2.082520e-01  3.884888e-02    11.17
# 109  5.419922e-01 -3.061523e-01    11.07
# 110 -1.086914e+00 -6.250000e-02    11.24
# 111 -6.557617e-01  7.385254e-02    11.12
# 112 -8.041992e-01 -2.164307e-01    11.33
# 113 -3.007812e-01 -3.059387e-02    11.39
# 114 -1.654053e-01 -1.315918e-01    11.53
# 115  6.030273e-02 -2.069092e-01    11.41
# 116 -4.792480e-01 -5.207062e-03    11.47
# 117 -4.611816e-01 -7.568359e-02    11.38
# 118 -2.871094e-01  3.038025e-02    11.38
# 119 -2.177734e-01  3.061523e-01    11.17
# 120  4.799805e-01 -1.668701e-01    11.31
# 121  4.394531e-01 -9.100342e-02    11.23
# 122 -4.165039e-01  6.768799e-02    11.36
# 123  4.118652e-01  6.893158e-03    11.32
# 124 -4.821777e-02  1.397705e-01    11.29
# 125 -1.280518e-01  2.883301e-01    11.03
# 126  4.504395e-01  3.065491e-02    11.18
# 127  1.205444e-01 -1.359863e-01    11.21
# 128  2.871094e-01  2.514648e-01    11.29
# 129 -3.247070e-01  4.037476e-02    11.38
# 130  1.734619e-01 -7.238770e-02    11.35
# 131  6.157227e-01  6.829834e-02    11.28
# 132  4.340820e-01  1.528168e-02    11.31
# 133 -1.781006e-01  2.069092e-01    11.22
# 134  2.814941e-01 -1.406250e-01    11.42
# 135  1.289062e-01 -1.157379e-02    11.39
# 136  8.044434e-02 -1.801758e-01    11.37
# 137  2.556152e-01 -1.530762e-01    11.39

# %%
print(df.shape)
print(df_train.shape)
print(df_test.shape)
# Out:
# (1097231, 138)
# (590540, 357)
# (506691, 357)

# %%
df_train_v4 = df.iloc[:590540, :]
df_test_v4 = df.iloc[590540:, :]

# %%
Y_train.sum()
# Out:
# 20663

# %%
df_test_v4.describe()
# Out:
#               index  TransactionID  TransactionDT  TransactionAmt  \
# count  506691.00000   5.066910e+05   5.066910e+05   506691.000000
# mean   253345.00000   3.916894e+06   2.692994e+07       -0.015160
# std    146269.23696   1.462692e+05   4.756507e+06        0.000000
# min         0.00000   3.663549e+06   1.840322e+07       -4.574219
# 25%    126672.50000   3.790222e+06   2.277154e+07       -0.691406
# 50%    253345.00000   3.916894e+06   2.720466e+07       -0.143066
# 75%    380017.50000   4.043566e+06   3.134856e+07        0.489502
# max    506690.00000   4.170239e+06   3.421434e+07        5.113281
#
#            ProductCD          card1          card2          card3  \
# count  506691.000000  506691.000000  506691.000000  506691.000000
# mean        3.116039    8797.759258     267.787727      54.014166
# std         1.493833    4798.697339     160.302997      13.823694
# min         0.000000       1.000000       0.000000       0.000000
# 25%         2.000000    4927.000000     115.000000      50.000000
# 50%         4.000000    8642.000000     275.000000      50.000000
# 75%         4.000000   13040.000000     414.000000      50.000000
# max         4.000000   17090.000000     501.000000     133.000000
#
#                card4          card5  ...       PCA_V_40       PCA_V_41  \
# count  506691.000000  506691.000000  ...  506691.000000  506691.000000
# mean        3.291941     100.502521  ...      -0.007080       0.010887
# std         1.023213      40.537396  ...       0.000000       0.000000
# min         0.000000       0.000000  ...     -18.015625     -36.562500
# 25%         2.000000      66.000000  ...      -0.313477      -0.296631
# 50%         4.000000     126.000000  ...      -0.002310       0.002550
# 75%         4.000000     126.000000  ...       0.251465       0.176270
# max         4.000000     138.000000  ...      28.171875      27.015625
#
#             PCA_V_42       PCA_V_43       PCA_V_44       PCA_V_45  \
# count  506691.000000  506691.000000  506691.000000  506691.000000
# mean        0.010979      -0.005878      -0.020111      -0.002537
# std         0.000000       0.000000       0.000000       0.000000
# min       -22.906250     -29.968750     -27.859375     -16.171875
# 25%        -0.251221      -0.312500      -0.240479      -0.267090
# 50%        -0.034332       0.068298       0.015282       0.030762
# 75%         0.218750       0.234497       0.250244       0.305908
# max        33.875000      23.750000      30.312500      55.375000
#
#             PCA_V_46       PCA_V_47       PCA_V_48       PCA_V_49
# count  506691.000000  506691.000000  506691.000000  506691.000000
# mean       -0.009407      -0.005287      -0.001277      -0.000007
# std         0.000000       0.000000       0.000000       0.000000
# min       -30.859375     -24.250000     -21.921875     -24.468750
# 25%        -0.254150      -0.245239      -0.180176      -0.207397
# 50%        -0.046295      -0.058411      -0.026291       0.033234
# 75%         0.156006       0.201050       0.263428       0.256104
# max        31.359375      31.390625      42.625000      41.125000
#
# [8 rows x 138 columns]

# %%
# Ver4
df_train_v4.to_pickle("../Data/Training_set_ver4.pkl")
df_test_v4.to_pickle("../Data/Test_set_ver4.pkl")
Y_train.to_pickle("../Data/Training_set_Y_ver4.pkl")

# %%
df_train_v4 = pd.read_pickle("../Data/Training_set_ver4.pkl")
df_test_v4 = pd.read_pickle("../Data/Test_set_ver4.pkl")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
from sklearn import preprocessing
import seaborn as sns
import pickle as pkl

import math
import tensorflow as tf
from keras import layers, regularizers
from keras.layers import Dense, Activation, Input, Concatenate, Embedding, Flatten, Dropout, BatchNormalization, SpatialDropout1D
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from keras.initializers import glorot_uniform
import keras.backend as K
from keras.models import Model, load_model, Sequential
from keras import optimizers

import sklearn
from sklearn.metrics import precision_score, recall_score, confusion_matrix, accuracy_score, roc_auc_score, f1_score, roc_curve, auc,precision_recall_curve
# Out:
# Using TensorFlow backend.

# %%
numerical

# %%
def get_input_features(df):
    X = {'numerical':np.array(df[numerical])}
    for col in categorical:
        X[col] = np.array(df[col])
    return X

def fc_nn_with_el():
    categorical_inputs = []
    for col in categorical:
        categorical_inputs.append(Input(shape=[1], name = col))
        
    categorical_embeddings = []
    for i, col in enumerate(categorical):
        categorical_embeddings.append(
            Embedding(category_counts[col], int(np.log1p(category_counts[col])+1), name = col+"_emb")(categorical_inputs[i]))
    
    categorical_logits = Concatenate(name = "categorical_conc")(
        [Flatten()(SpatialDropout1D(.1)(col_emb)) for col_emb in categorical_embeddings])
    
    numerical_inputs = Input(shape=[df_train_v4[numerical].shape[1]], name = "numerical")
    numerical_logits = Dropout(.1)(numerical_inputs)
    
    x = Concatenate()([categorical_logits, numerical_logits])
    
    x = Dense(200, activation = 'relu')(x)
    x = Dropout(.2)(x)
    x = Dense(150, activation = 'relu')(x)
    x = Dropout(.2)(x)
    output = Dense(1, activation = 'sigmoid')(x)
    
    model = Model(inputs = categorical_inputs + [numerical_inputs], outputs = output)
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy')
    return model

# %%
len(category_counts) == len(categorical)
# Out:
# True

# %%
X_train = get_input_features(df_train_v4)

# %%
Y_train.sum()

# %%
    model = fc_nn_with_el()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0811 08:14:35.668659 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0811 08:14:35.718375 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0811 08:14:36.118458 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0811 08:14:36.125022 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0811 08:14:36.130410 4378899904 deprecation.py:506] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0811 08:14:37.798884 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0811 08:14:37.817012 4378899904 deprecation_wrapper.py:119] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0811 08:14:37.821806 4378899904 deprecation.py:323] From /Users/ic3scar/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
filepath = "../Data/NN_EL_Model_ver2_4.h5"
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,
                              patience=30, min_lr=0.00001, verbose=1)
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callback_list = [checkpoint, reduce_lr]

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# ProductCD (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# card1 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# card2 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# card3 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# card4 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# card5 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# card6 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# addr1 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# addr2 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# P_emaildomain (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# R_emaildomain (InputLayer)      (None, 1)            0
# __________________________________________________________________________________________________
# M1 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M2 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M3 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M4 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M5 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M6 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M7 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M8 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# M9 (InputLayer)                 (None, 1)            0
# __________________________________________________________________________________________________
# DeviceType (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# DeviceInfo (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# Weekday (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# Hour (InputLayer)               (None, 1)            0
# __________________________________________________________________________________________________
# P_emaildomain_pre (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# P_emaildomain_suffix (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# R_emaildomain_pre (InputLayer)  (None, 1)            0
# __________________________________________________________________________________________________
# R_emaildomain_suffix (InputLaye (None, 1)            0
# __________________________________________________________________________________________________
# id_12 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_13 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_14 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_15 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_16 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_17 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_19 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_20 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_28 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_29 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_30 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_31 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_32 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_33 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_34 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_35 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_36 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_37 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# id_38 (InputLayer)              (None, 1)            0
# __________________________________________________________________________________________________
# ProductCD_emb (Embedding)       (None, 1, 2)         12          ProductCD[0][0]
# __________________________________________________________________________________________________
# card1_emb (Embedding)           (None, 1, 10)        170920      card1[0][0]
# __________________________________________________________________________________________________
# card2_emb (Embedding)           (None, 1, 7)         3521        card2[0][0]
# __________________________________________________________________________________________________
# card3_emb (Embedding)           (None, 1, 5)         675         card3[0][0]
# __________________________________________________________________________________________________
# card4_emb (Embedding)           (None, 1, 2)         12          card4[0][0]
# __________________________________________________________________________________________________
# card5_emb (Embedding)           (None, 1, 5)         700         card5[0][0]
# __________________________________________________________________________________________________
# card6_emb (Embedding)           (None, 1, 2)         12          card6[0][0]
# __________________________________________________________________________________________________
# addr1_emb (Embedding)           (None, 1, 7)         3101        addr1[0][0]
# __________________________________________________________________________________________________
# addr2_emb (Embedding)           (None, 1, 5)         475         addr2[0][0]
# __________________________________________________________________________________________________
# P_emaildomain_emb (Embedding)   (None, 1, 5)         310         P_emaildomain[0][0]
# __________________________________________________________________________________________________
# R_emaildomain_emb (Embedding)   (None, 1, 5)         310         R_emaildomain[0][0]
# __________________________________________________________________________________________________
# M1_emb (Embedding)              (None, 1, 2)         8           M1[0][0]
# __________________________________________________________________________________________________
# M2_emb (Embedding)              (None, 1, 2)         8           M2[0][0]
# __________________________________________________________________________________________________
# M3_emb (Embedding)              (None, 1, 2)         8           M3[0][0]
# __________________________________________________________________________________________________
# M4_emb (Embedding)              (None, 1, 2)         10          M4[0][0]
# __________________________________________________________________________________________________
# M5_emb (Embedding)              (None, 1, 2)         8           M5[0][0]
# __________________________________________________________________________________________________
# M6_emb (Embedding)              (None, 1, 2)         8           M6[0][0]
# __________________________________________________________________________________________________
# M7_emb (Embedding)              (None, 1, 2)         8           M7[0][0]
# __________________________________________________________________________________________________
# M8_emb (Embedding)              (None, 1, 2)         8           M8[0][0]
# __________________________________________________________________________________________________
# M9_emb (Embedding)              (None, 1, 2)         8           M9[0][0]
# __________________________________________________________________________________________________
# DeviceType_emb (Embedding)      (None, 1, 2)         8           DeviceType[0][0]
# __________________________________________________________________________________________________
# DeviceInfo_emb (Embedding)      (None, 1, 8)         22408       DeviceInfo[0][0]
# __________________________________________________________________________________________________
# Weekday_emb (Embedding)         (None, 1, 3)         24          Weekday[0][0]
# __________________________________________________________________________________________________
# Hour_emb (Embedding)            (None, 1, 4)         100         Hour[0][0]
# __________________________________________________________________________________________________
# P_emaildomain_pre_emb (Embeddin (None, 1, 3)         30          P_emaildomain_pre[0][0]
# __________________________________________________________________________________________________
# P_emaildomain_suffix_emb (Embed (None, 1, 3)         30          P_emaildomain_suffix[0][0]
# __________________________________________________________________________________________________
# R_emaildomain_pre_emb (Embeddin (None, 1, 3)         30          R_emaildomain_pre[0][0]
# __________________________________________________________________________________________________
# R_emaildomain_suffix_emb (Embed (None, 1, 3)         30          R_emaildomain_suffix[0][0]
# __________________________________________________________________________________________________
# id_12_emb (Embedding)           (None, 1, 2)         8           id_12[0][0]
# __________________________________________________________________________________________________
# id_13_emb (Embedding)           (None, 1, 5)         285         id_13[0][0]
# __________________________________________________________________________________________________
# id_14_emb (Embedding)           (None, 1, 4)         120         id_14[0][0]
# __________________________________________________________________________________________________
# id_15_emb (Embedding)           (None, 1, 2)         10          id_15[0][0]
# __________________________________________________________________________________________________
# id_16_emb (Embedding)           (None, 1, 2)         8           id_16[0][0]
# __________________________________________________________________________________________________
# id_17_emb (Embedding)           (None, 1, 5)         645         id_17[0][0]
# __________________________________________________________________________________________________
# id_19_emb (Embedding)           (None, 1, 7)         3990        id_19[0][0]
# __________________________________________________________________________________________________
# id_20_emb (Embedding)           (None, 1, 7)         3843        id_20[0][0]
# __________________________________________________________________________________________________
# id_28_emb (Embedding)           (None, 1, 2)         8           id_28[0][0]
# __________________________________________________________________________________________________
# id_29_emb (Embedding)           (None, 1, 2)         8           id_29[0][0]
# __________________________________________________________________________________________________
# id_30_emb (Embedding)           (None, 1, 5)         440         id_30[0][0]
# __________________________________________________________________________________________________
# id_31_emb (Embedding)           (None, 1, 6)         1038        id_31[0][0]
# __________________________________________________________________________________________________
# id_32_emb (Embedding)           (None, 1, 3)         24          id_32[0][0]
# __________________________________________________________________________________________________
# id_33_emb (Embedding)           (None, 1, 7)         3241        id_33[0][0]
# __________________________________________________________________________________________________
# id_34_emb (Embedding)           (None, 1, 2)         12          id_34[0][0]
# __________________________________________________________________________________________________
# id_35_emb (Embedding)           (None, 1, 2)         8           id_35[0][0]
# __________________________________________________________________________________________________
# id_36_emb (Embedding)           (None, 1, 2)         8           id_36[0][0]
# __________________________________________________________________________________________________
# id_37_emb (Embedding)           (None, 1, 2)         8           id_37[0][0]
# __________________________________________________________________________________________________
# id_38_emb (Embedding)           (None, 1, 2)         8           id_38[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 1, 2)         0           ProductCD_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_2 (SpatialDro (None, 1, 10)        0           card1_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_3 (SpatialDro (None, 1, 7)         0           card2_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 1, 5)         0           card3_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 1, 2)         0           card4_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_6 (SpatialDro (None, 1, 5)         0           card5_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 1, 2)         0           card6_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_8 (SpatialDro (None, 1, 7)         0           addr1_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 1, 5)         0           addr2_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_10 (SpatialDr (None, 1, 5)         0           P_emaildomain_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_11 (SpatialDr (None, 1, 5)         0           R_emaildomain_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_12 (SpatialDr (None, 1, 2)         0           M1_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_13 (SpatialDr (None, 1, 2)         0           M2_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_14 (SpatialDr (None, 1, 2)         0           M3_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_15 (SpatialDr (None, 1, 2)         0           M4_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_16 (SpatialDr (None, 1, 2)         0           M5_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_17 (SpatialDr (None, 1, 2)         0           M6_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_18 (SpatialDr (None, 1, 2)         0           M7_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_19 (SpatialDr (None, 1, 2)         0           M8_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_20 (SpatialDr (None, 1, 2)         0           M9_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_21 (SpatialDr (None, 1, 2)         0           DeviceType_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_22 (SpatialDr (None, 1, 8)         0           DeviceInfo_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_23 (SpatialDr (None, 1, 3)         0           Weekday_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_24 (SpatialDr (None, 1, 4)         0           Hour_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_25 (SpatialDr (None, 1, 3)         0           P_emaildomain_pre_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_26 (SpatialDr (None, 1, 3)         0           P_emaildomain_suffix_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_27 (SpatialDr (None, 1, 3)         0           R_emaildomain_pre_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_28 (SpatialDr (None, 1, 3)         0           R_emaildomain_suffix_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_29 (SpatialDr (None, 1, 2)         0           id_12_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_30 (SpatialDr (None, 1, 5)         0           id_13_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_31 (SpatialDr (None, 1, 4)         0           id_14_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_32 (SpatialDr (None, 1, 2)         0           id_15_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_33 (SpatialDr (None, 1, 2)         0           id_16_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_34 (SpatialDr (None, 1, 5)         0           id_17_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_35 (SpatialDr (None, 1, 7)         0           id_19_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_36 (SpatialDr (None, 1, 7)         0           id_20_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_37 (SpatialDr (None, 1, 2)         0           id_28_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_38 (SpatialDr (None, 1, 2)         0           id_29_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_39 (SpatialDr (None, 1, 5)         0           id_30_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_40 (SpatialDr (None, 1, 6)         0           id_31_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_41 (SpatialDr (None, 1, 3)         0           id_32_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_42 (SpatialDr (None, 1, 7)         0           id_33_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_43 (SpatialDr (None, 1, 2)         0           id_34_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_44 (SpatialDr (None, 1, 2)         0           id_35_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_45 (SpatialDr (None, 1, 2)         0           id_36_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_46 (SpatialDr (None, 1, 2)         0           id_37_emb[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_47 (SpatialDr (None, 1, 2)         0           id_38_emb[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2)            0           spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 10)           0           spatial_dropout1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 7)            0           spatial_dropout1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 5)            0           spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 2)            0           spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 5)            0           spatial_dropout1d_6[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 2)            0           spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 7)            0           spatial_dropout1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 5)            0           spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 5)            0           spatial_dropout1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 5)            0           spatial_dropout1d_11[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 2)            0           spatial_dropout1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 2)            0           spatial_dropout1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 2)            0           spatial_dropout1d_14[0][0]
# __________________________________________________________________________________________________
# flatten_15 (Flatten)            (None, 2)            0           spatial_dropout1d_15[0][0]
# __________________________________________________________________________________________________
# flatten_16 (Flatten)            (None, 2)            0           spatial_dropout1d_16[0][0]
# __________________________________________________________________________________________________
# flatten_17 (Flatten)            (None, 2)            0           spatial_dropout1d_17[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 2)            0           spatial_dropout1d_18[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 2)            0           spatial_dropout1d_19[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 2)            0           spatial_dropout1d_20[0][0]
# __________________________________________________________________________________________________
# flatten_21 (Flatten)            (None, 2)            0           spatial_dropout1d_21[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 8)            0           spatial_dropout1d_22[0][0]
# __________________________________________________________________________________________________
# flatten_23 (Flatten)            (None, 3)            0           spatial_dropout1d_23[0][0]
# __________________________________________________________________________________________________
# flatten_24 (Flatten)            (None, 4)            0           spatial_dropout1d_24[0][0]
# __________________________________________________________________________________________________
# flatten_25 (Flatten)            (None, 3)            0           spatial_dropout1d_25[0][0]
# __________________________________________________________________________________________________
# flatten_26 (Flatten)            (None, 3)            0           spatial_dropout1d_26[0][0]
# __________________________________________________________________________________________________
# flatten_27 (Flatten)            (None, 3)            0           spatial_dropout1d_27[0][0]
# __________________________________________________________________________________________________
# flatten_28 (Flatten)            (None, 3)            0           spatial_dropout1d_28[0][0]
# __________________________________________________________________________________________________
# flatten_29 (Flatten)            (None, 2)            0           spatial_dropout1d_29[0][0]
# __________________________________________________________________________________________________
# flatten_30 (Flatten)            (None, 5)            0           spatial_dropout1d_30[0][0]
# __________________________________________________________________________________________________
# flatten_31 (Flatten)            (None, 4)            0           spatial_dropout1d_31[0][0]
# __________________________________________________________________________________________________
# flatten_32 (Flatten)            (None, 2)            0           spatial_dropout1d_32[0][0]
# __________________________________________________________________________________________________
# flatten_33 (Flatten)            (None, 2)            0           spatial_dropout1d_33[0][0]
# __________________________________________________________________________________________________
# flatten_34 (Flatten)            (None, 5)            0           spatial_dropout1d_34[0][0]
# __________________________________________________________________________________________________
# flatten_35 (Flatten)            (None, 7)            0           spatial_dropout1d_35[0][0]
# __________________________________________________________________________________________________
# flatten_36 (Flatten)            (None, 7)            0           spatial_dropout1d_36[0][0]
# __________________________________________________________________________________________________
# flatten_37 (Flatten)            (None, 2)            0           spatial_dropout1d_37[0][0]
# __________________________________________________________________________________________________
# flatten_38 (Flatten)            (None, 2)            0           spatial_dropout1d_38[0][0]
# __________________________________________________________________________________________________
# flatten_39 (Flatten)            (None, 5)            0           spatial_dropout1d_39[0][0]
# __________________________________________________________________________________________________
# flatten_40 (Flatten)            (None, 6)            0           spatial_dropout1d_40[0][0]
# __________________________________________________________________________________________________
# flatten_41 (Flatten)            (None, 3)            0           spatial_dropout1d_41[0][0]
# __________________________________________________________________________________________________
# flatten_42 (Flatten)            (None, 7)            0           spatial_dropout1d_42[0][0]
# __________________________________________________________________________________________________
# flatten_43 (Flatten)            (None, 2)            0           spatial_dropout1d_43[0][0]
# __________________________________________________________________________________________________
# flatten_44 (Flatten)            (None, 2)            0           spatial_dropout1d_44[0][0]
# __________________________________________________________________________________________________
# flatten_45 (Flatten)            (None, 2)            0           spatial_dropout1d_45[0][0]
# __________________________________________________________________________________________________
# flatten_46 (Flatten)            (None, 2)            0           spatial_dropout1d_46[0][0]
# __________________________________________________________________________________________________
# flatten_47 (Flatten)            (None, 2)            0           spatial_dropout1d_47[0][0]
# __________________________________________________________________________________________________
# numerical (InputLayer)          (None, 58)           0
# __________________________________________________________________________________________________
# categorical_conc (Concatenate)  (None, 171)          0           flatten_1[0][0]
#                                                                  flatten_2[0][0]
#                                                                  flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
#                                                                  flatten_6[0][0]
#                                                                  flatten_7[0][0]
#                                                                  flatten_8[0][0]
#                                                                  flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
#                                                                  flatten_12[0][0]
#                                                                  flatten_13[0][0]
#                                                                  flatten_14[0][0]
#                                                                  flatten_15[0][0]
#                                                                  flatten_16[0][0]
#                                                                  flatten_17[0][0]
#                                                                  flatten_18[0][0]
#                                                                  flatten_19[0][0]
#                                                                  flatten_20[0][0]
#                                                                  flatten_21[0][0]
#                                                                  flatten_22[0][0]
#                                                                  flatten_23[0][0]
#                                                                  flatten_24[0][0]
#                                                                  flatten_25[0][0]
#                                                                  flatten_26[0][0]
#                                                                  flatten_27[0][0]
#                                                                  flatten_28[0][0]
#                                                                  flatten_29[0][0]
#                                                                  flatten_30[0][0]
#                                                                  flatten_31[0][0]
#                                                                  flatten_32[0][0]
#                                                                  flatten_33[0][0]
#                                                                  flatten_34[0][0]
#                                                                  flatten_35[0][0]
#                                                                  flatten_36[0][0]
#                                                                  flatten_37[0][0]
#                                                                  flatten_38[0][0]
#                                                                  flatten_39[0][0]
#                                                                  flatten_40[0][0]
#                                                                  flatten_41[0][0]
#                                                                  flatten_42[0][0]
#                                                                  flatten_43[0][0]
#                                                                  flatten_44[0][0]
#                                                                  flatten_45[0][0]
#                                                                  flatten_46[0][0]
#                                                                  flatten_47[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 58)           0           numerical[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 229)          0           categorical_conc[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          46000       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 200)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 150)          30150       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 150)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            151         dropout_3[0][0]
# ==================================================================================================
# Total params: 292,795
# Trainable params: 292,795
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, Y_train, epochs = 100, batch_size = 1024, callbacks = callback_list)
# Out:
# Epoch 1/100
# 590540/590540 [==============================] - 16s 27us/step - loss: 0.1107 - acc: 0.9686
#
# Epoch 00001: loss improved from inf to 0.11073, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 2/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0834 - acc: 0.9759
#
# Epoch 00002: loss improved from 0.11073 to 0.08341, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 3/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0781 - acc: 0.9774
#
# Epoch 00003: loss improved from 0.08341 to 0.07807, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 4/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0744 - acc: 0.9786
#
# Epoch 00004: loss improved from 0.07807 to 0.07442, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 5/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0719 - acc: 0.9793
#
# Epoch 00005: loss improved from 0.07442 to 0.07187, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 6/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0690 - acc: 0.9799
#
# Epoch 00006: loss improved from 0.07187 to 0.06901, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 7/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0665 - acc: 0.9805
#
# Epoch 00007: loss improved from 0.06901 to 0.06648, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 8/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0644 - acc: 0.9812
#
# Epoch 00008: loss improved from 0.06648 to 0.06443, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 9/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0626 - acc: 0.9816
#
# Epoch 00009: loss improved from 0.06443 to 0.06262, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 10/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0608 - acc: 0.9821
#
# Epoch 00010: loss improved from 0.06262 to 0.06083, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 11/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0590 - acc: 0.9826
#
# Epoch 00011: loss improved from 0.06083 to 0.05902, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 12/100
# 590540/590540 [==============================] - 12s 20us/step - loss: 0.0574 - acc: 0.9831
#
# Epoch 00012: loss improved from 0.05902 to 0.05745, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 13/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0559 - acc: 0.9835
#
# Epoch 00013: loss improved from 0.05745 to 0.05592, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 14/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0549 - acc: 0.9836
#
# Epoch 00014: loss improved from 0.05592 to 0.05490, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 15/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0533 - acc: 0.9841
#
# Epoch 00015: loss improved from 0.05490 to 0.05327, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 16/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0523 - acc: 0.9844
#
# Epoch 00016: loss improved from 0.05327 to 0.05228, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 17/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0514 - acc: 0.9847
#
# Epoch 00017: loss improved from 0.05228 to 0.05137, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 18/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0501 - acc: 0.9849
#
# Epoch 00018: loss improved from 0.05137 to 0.05014, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 19/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0494 - acc: 0.9852
#
# Epoch 00019: loss improved from 0.05014 to 0.04939, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 20/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0482 - acc: 0.9855
#
# Epoch 00020: loss improved from 0.04939 to 0.04823, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 21/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0477 - acc: 0.9856
#
# Epoch 00021: loss improved from 0.04823 to 0.04765, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 22/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0469 - acc: 0.9859
#
# Epoch 00022: loss improved from 0.04765 to 0.04691, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 23/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0459 - acc: 0.9861
#
# Epoch 00023: loss improved from 0.04691 to 0.04587, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 24/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0456 - acc: 0.9863
#
# Epoch 00024: loss improved from 0.04587 to 0.04556, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 25/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0451 - acc: 0.9863
#
# Epoch 00025: loss improved from 0.04556 to 0.04515, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 26/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0445 - acc: 0.9866
#
# Epoch 00026: loss improved from 0.04515 to 0.04449, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 27/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0440 - acc: 0.9867
#
# Epoch 00027: loss improved from 0.04449 to 0.04397, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 28/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0432 - acc: 0.9869
#
# Epoch 00028: loss improved from 0.04397 to 0.04322, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 29/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0430 - acc: 0.9869
#
# Epoch 00029: loss improved from 0.04322 to 0.04295, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 30/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0425 - acc: 0.9870
#
# Epoch 00030: loss improved from 0.04295 to 0.04254, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 31/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0421 - acc: 0.9871
#
# Epoch 00031: loss improved from 0.04254 to 0.04210, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 32/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0415 - acc: 0.9873
#
# Epoch 00032: loss improved from 0.04210 to 0.04153, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 33/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0416 - acc: 0.9873 0s - loss: 0.0415 - acc: 0.98
#
# Epoch 00033: loss did not improve from 0.04153
# Epoch 34/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0413 - acc: 0.9874
#
# Epoch 00034: loss improved from 0.04153 to 0.04127, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 35/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0410 - acc: 0.9875
#
# Epoch 00035: loss improved from 0.04127 to 0.04101, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 36/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0402 - acc: 0.9877
#
# Epoch 00036: loss improved from 0.04101 to 0.04017, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 37/100
# 590540/590540 [==============================] - 15s 25us/step - loss: 0.0402 - acc: 0.9877
#
# Epoch 00037: loss did not improve from 0.04017
# Epoch 38/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0398 - acc: 0.9878
#
# Epoch 00038: loss improved from 0.04017 to 0.03985, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 39/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0396 - acc: 0.9881
#
# Epoch 00039: loss improved from 0.03985 to 0.03955, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 40/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0392 - acc: 0.9880
#
# Epoch 00040: loss improved from 0.03955 to 0.03920, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 41/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0391 - acc: 0.9880
#
# Epoch 00041: loss improved from 0.03920 to 0.03909, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 42/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0386 - acc: 0.9883
#
# Epoch 00042: loss improved from 0.03909 to 0.03859, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 43/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0386 - acc: 0.9882
#
# Epoch 00043: loss did not improve from 0.03859
# Epoch 44/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0381 - acc: 0.9884 1s - loss: 0.0
#
# Epoch 00044: loss improved from 0.03859 to 0.03810, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 45/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0379 - acc: 0.9884 1s -
#
# Epoch 00045: loss improved from 0.03810 to 0.03785, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 46/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0377 - acc: 0.9884
#
# Epoch 00046: loss improved from 0.03785 to 0.03768, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 47/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0378 - acc: 0.9884
#
# Epoch 00047: loss did not improve from 0.03768
# Epoch 48/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0375 - acc: 0.9884 1s - - ETA: 0s - loss: 0.0374 - acc: 0.98
#
# Epoch 00048: loss improved from 0.03768 to 0.03749, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 49/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0369 - acc: 0.9888 2s - l - ETA: 1s - loss: 0.036 - ETA: 0s - loss: 0.0369 - acc: 0.9
#
# Epoch 00049: loss improved from 0.03749 to 0.03690, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 50/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0364 - acc: 0.9888
#
# Epoch 00050: loss improved from 0.03690 to 0.03645, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 51/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0366 - acc: 0.9889
#
# Epoch 00051: loss did not improve from 0.03645
# Epoch 52/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0365 - acc: 0.9888 4s - ET
#
# Epoch 00052: loss did not improve from 0.03645
# Epoch 53/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0358 - acc: 0.9889 0s - loss: 0.0358 - acc:
#
# Epoch 00053: loss improved from 0.03645 to 0.03583, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 54/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0360 - acc: 0.9888 1s
#
# Epoch 00054: loss did not improve from 0.03583
# Epoch 55/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0360 - acc: 0.9889
#
# Epoch 00055: loss did not improve from 0.03583
# Epoch 56/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0359 - acc: 0.9889
#
# Epoch 00056: loss did not improve from 0.03583
# Epoch 57/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0354 - acc: 0.9891 6s -  - E - ETA: 2s  - ETA: 0s - loss: 0.0355 -
#
# Epoch 00057: loss improved from 0.03583 to 0.03537, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 58/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0355 - acc: 0.9891
#
# Epoch 00058: loss did not improve from 0.03537
# Epoch 59/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0354 - acc: 0.9891
#
# Epoch 00059: loss did not improve from 0.03537
# Epoch 60/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0352 - acc: 0.9891
#
# Epoch 00060: loss improved from 0.03537 to 0.03516, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 61/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0345 - acc: 0.9893 4s - los  - ETA: 0s - loss: 0.0346 - acc: 0.98
#
# Epoch 00061: loss improved from 0.03516 to 0.03455, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 62/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0349 - acc: 0.9892
#
# Epoch 00062: loss did not improve from 0.03455
# Epoch 63/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0351 - acc: 0.9891
#
# Epoch 00063: loss did not improve from 0.03455
# Epoch 64/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0343 - acc: 0.9893
#
# Epoch 00064: loss improved from 0.03455 to 0.03428, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 65/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0344 - acc: 0.9895
#
# Epoch 00065: loss did not improve from 0.03428
# Epoch 66/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0341 - acc: 0.9896
#
# Epoch 00066: loss improved from 0.03428 to 0.03412, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 67/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0341 - acc: 0.9895
#
# Epoch 00067: loss improved from 0.03412 to 0.03405, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 68/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0341 - acc: 0.9896
#
# Epoch 00068: loss improved from 0.03405 to 0.03405, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 69/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0339 - acc: 0.9896
#
# Epoch 00069: loss improved from 0.03405 to 0.03395, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 70/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0341 - acc: 0.9895
#
# Epoch 00070: loss did not improve from 0.03395
# Epoch 71/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0333 - acc: 0.9896
#
# Epoch 00071: loss improved from 0.03395 to 0.03329, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 72/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0338 - acc: 0.9896
#
# Epoch 00072: loss did not improve from 0.03329
# Epoch 73/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0333 - acc: 0.9896
#
# Epoch 00073: loss did not improve from 0.03329
# Epoch 74/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0337 - acc: 0.9896
#
# Epoch 00074: loss did not improve from 0.03329
# Epoch 75/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0330 - acc: 0.9899
#
# Epoch 00075: loss improved from 0.03329 to 0.03295, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 76/100
# 590540/590540 [==============================] - 14s 23us/step - loss: 0.0329 - acc: 0.9899
#
# Epoch 00076: loss improved from 0.03295 to 0.03285, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 77/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0331 - acc: 0.9898
#
# Epoch 00077: loss did not improve from 0.03285
# Epoch 78/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0328 - acc: 0.9898
#
# Epoch 00078: loss improved from 0.03285 to 0.03283, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 79/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0330 - acc: 0.9899
#
# Epoch 00079: loss did not improve from 0.03283
# Epoch 80/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0329 - acc: 0.9899
#
# Epoch 00080: loss did not improve from 0.03283
# Epoch 81/100
# 590540/590540 [==============================] - 15s 25us/step - loss: 0.0324 - acc: 0.9898
#
# Epoch 00081: loss improved from 0.03283 to 0.03243, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 82/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0326 - acc: 0.9899
#
# Epoch 00082: loss did not improve from 0.03243
# Epoch 83/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0329 - acc: 0.9898
#
# Epoch 00083: loss did not improve from 0.03243
# Epoch 84/100
# 590540/590540 [==============================] - 14s 24us/step - loss: 0.0327 - acc: 0.9899
#
# Epoch 00084: loss did not improve from 0.03243
# Epoch 85/100
# 590540/590540 [==============================] - 14s 25us/step - loss: 0.0324 - acc: 0.9899
#
# Epoch 00085: loss improved from 0.03243 to 0.03242, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 86/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0324 - acc: 0.9900 1s - loss: 0 - ETA: 0s - loss: 0.0325 -
#
# Epoch 00086: loss improved from 0.03242 to 0.03238, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 87/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0322 - acc: 0.9901 0s - loss: 0.0322 - acc: 0.99
#
# Epoch 00087: loss improved from 0.03238 to 0.03222, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 88/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0320 - acc: 0.9901
#
# Epoch 00088: loss improved from 0.03222 to 0.03197, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 89/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0319 - acc: 0.9901
#
# Epoch 00089: loss improved from 0.03197 to 0.03190, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 90/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0319 - acc: 0.9902
#
# Epoch 00090: loss did not improve from 0.03190
# Epoch 91/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0319 - acc: 0.9900
#
# Epoch 00091: loss improved from 0.03190 to 0.03189, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 92/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0315 - acc: 0.9903 1s - lo
#
# Epoch 00092: loss improved from 0.03189 to 0.03151, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 93/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0313 - acc: 0.9902
#
# Epoch 00093: loss improved from 0.03151 to 0.03132, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 94/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0316 - acc: 0.9901
#
# Epoch 00094: loss did not improve from 0.03132
# Epoch 95/100
# 590540/590540 [==============================] - 13s 23us/step - loss: 0.0311 - acc: 0.9902
#
# Epoch 00095: loss improved from 0.03132 to 0.03112, saving model to ../Data/NN_EL_Model_ver2_4.h5
# Epoch 96/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0314 - acc: 0.9903 7s - loss: 0 - ETA: 6s - loss: 0.0
#
# Epoch 00096: loss did not improve from 0.03112
# Epoch 97/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0312 - acc: 0.9903
#
# Epoch 00097: loss did not improve from 0.03112
# Epoch 98/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0312 - acc: 0.9902
#
# Epoch 00098: loss did not improve from 0.03112
# Epoch 99/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0313 - acc: 0.9901 0s - loss: 0.0312 - ac
#
# Epoch 00099: loss did not improve from 0.03112
# Epoch 100/100
# 590540/590540 [==============================] - 13s 22us/step - loss: 0.0312 - acc: 0.9903
#
# Epoch 00100: loss did not improve from 0.03112

# %%
preds = model.predict(X_train)

# %%
print(roc_auc_score(Y_train, preds))
# Out:
# 0.9978300515091033

# %%
print(sklearn.metrics.f1_score(Y_train, preds>0.5))
# Out:
# 0.9230090333298723

# %%
model2 = load_model("../Data/NN_EL_Model_ver2_4.h5")

# %%
X_test = get_input_features(df_test_v4)

# %%
predicts = model2.predict(X_test)

# %%
predicts.shape
# Out:
# (506691, 1)

# %%
# Need to correct input part into the model

# %%
predicts.sum()
# Out:
# 14257.663

# %%
submission = pd.read_csv('../Data/sample_submission.csv', index_col='TransactionID')
submission['isFraud'] = predicts
submission.to_csv('../Data/Y_test_v4.csv')

# %%
submission.shape
# Out:
# (506691, 1)

# %%
df_y.to_csv("../Data/test_ver3.csv", index=False)

# %%
plt.plot(history.history['loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
